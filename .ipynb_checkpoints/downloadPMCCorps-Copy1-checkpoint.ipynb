# %%
import codecs
import pandas as pd
import io
import random

filename2 = "product2.csv"
df = pd.read_csv(filename2)
df[['PROPRIETARYNAME']]
brand_names = df.PROPRIETARYNAME.sample(n=1000, random_state=1).unique()

from sklearn.model_selection import train_test_split
train_x, test_x, x, y = train_test_split((brand_names),(brand_names), test_size=0.2)

print(f"{len(train_x)} train_x")
print(f"{len(test_x)} test_x")
# Out:
# 720 train_x
# 180 test_x

# %%
import requests
import json
import pandas as pd

def downloadCorpsFromPMC(keyword):
    url = f"https://www.ebi.ac.uk/europepmc/webservices/rest/search?query={keyword}&resultType=core&cursorMark=*&pageSize=200&format=json"
    response = requests.get(url, allow_redirects=True)
    response.raise_for_status()
    prod_dict = json.loads(response.content)
    result = []    
    if(prod_dict['hitCount'] > 0):
        for item in prod_dict['resultList']['result']: 
            if('abstractText' in item):
                if(keyword in item['abstractText']):
                    result.append(item['abstractText'])               
            if('title' in item):
                if(keyword in item['title']):
                    result.append(item['title'])                
    print(f"{len(result)} found")
    return result

def download(keywords, output_file):
    f= open(output_file,"w+")
    result = []
    for keyword in keywords:
        print(f" keyword {keyword} load...")
        texts = downloadCorpsFromPMC(keyword)
        if(len(texts) > 0):
            for text in texts: 
                f.write(json.dumps({"keyword":keyword, "texts": text}) + "\n")
    f.close()

# %%
download(train_x, "pmc_ner_corps_train.json")
# Out:
#  keyword Sotalol load...
# 53 found
#  keyword WARMING load...
# 0 found
#  keyword Anticavity Fluoride Rinse load...
# 0 found
#  keyword Laxative load...
# 42 found
#  keyword Climara Pro load...
# 2 found
#  keyword SHISEIDO THE MAKEUP FOUNDATION load...
# 0 found
#  keyword Buprenorphine HCl and Naloxone HCl load...
# 0 found
#  keyword BANANA BOAT load...
# 0 found
#  keyword Hives load...
# 7 found
#  keyword Nizatidine load...
# 58 found
#  keyword MONTELUKAST SODIUM load...
# 51 found
#  keyword Salicylic Acid load...
# 59 found
#  keyword SNAIL SOLU TION EYE load...
# 0 found
#  keyword ACNE SOLUTIONS OIL CONTROL CLEANSING MASK load...
# 0 found
#  keyword E3 Foaming Hand Sanitizer load...
# 0 found
#  keyword Sinus load...
# 73 found
#  keyword Citalopram load...
# 70 found
#  keyword HGH Vitality load...
# 0 found
#  keyword Anti-Bacterial Wipes load...
# 0 found
#  keyword Daylogic Antibacterial Foaming Wash Refill load...
# 0 found
#  keyword Silver Sulfadiazine load...
# 21 found
#  keyword Levofloxacin load...
# 67 found
#  keyword Nateglinide load...
# 51 found
#  keyword Kids Crest load...
# 0 found
#  keyword Lidocaine load...
# 120 found
#  keyword Arnica Montana load...
# 18 found
#  keyword SUPER ORIGIN CERAMIDE BB load...
# 0 found
#  keyword Assorted Fruit panned chew load...
# 0 found
#  keyword Flormar BB BB02 Fair Light load...
# 0 found
#  keyword risperidone load...
# 193 found
#  keyword Colgate Total Advanced Fresh plus Whitening load...
# 0 found
#  keyword Antibacterial Moist Wipes load...
# 0 found
#  keyword Lisinopril with Hydrochlorothiazide load...
# 0 found
#  keyword Venlafaxine load...
# 89 found
#  keyword Sterile Water load...
# 11 found
#  keyword DT Whitening Anticavity Fluoride load...
# 0 found
#  keyword Quack Grass load...
# 0 found
#  keyword Casein load...
# 65 found
#  keyword Aripiprazole load...
# 121 found
#  keyword Tacrolimus load...
# 135 found
#  keyword Gemcitabine load...
# 120 found
#  keyword losartan potassium load...
# 146 found
#  keyword Animal Allergens, Guinea Pig Hair and Dander load...
# 0 found
#  keyword Ice Cold Topical Analgesic Gel load...
# 0 found
#  keyword Methylphenidate Hydrochloride (LA) load...
# 0 found
#  keyword Cefuroxime axetil load...
# 46 found
#  keyword DIABETIC SKIN CARE FORMULA load...
# 0 found
#  keyword Childrens Sudafed load...
# 0 found
#  keyword venlafaxine hydrochloride load...
# 131 found
#  keyword EZ Nite Sleep load...
# 0 found
#  keyword Sinus Relief Congestion and Cough load...
# 0 found
#  keyword Quality Choice Chewable Antacid load...
# 0 found
#  keyword Leader lansoprazole load...
# 0 found
#  keyword Daisy load...
# 4 found
#  keyword Abacavir load...
# 64 found
#  keyword Memantine Hydrochloride load...
# 6 found
#  keyword Valsartan and hydrochlorothiazide load...
# 5 found
#  keyword Black Walnut load...
# 22 found
#  keyword Isosorbide Mononitrate load...
# 14 found
#  keyword Privigen load...
# 50 found
#  keyword Cultivated Rye load...
# 1 found
#  keyword Sure Result DSS Premium Pak load...
# 0 found
#  keyword Galantamine load...
# 63 found
#  keyword Treatment Set TS350619 load...
# 0 found
#  keyword ATOVAQUONE load...
# 0 found
#  keyword Sulfacetamide Sodium load...
# 2 found
#  keyword Rhopressa load...
# 3 found
#  keyword Wet Wipes load...
# 8 found
#  keyword HAMSOA YUYU DEEP MOISTURE load...
# 0 found
#  keyword Menstrual Pain Relief load...
# 0 found
#  keyword LBEL EFFET PARFAIT LONG LASTING COMPACT SPF 15 load...
# 0 found
#  keyword CVS PHARMACY load...
# 0 found
#  keyword Piroxicam load...
# 62 found
#  keyword Fentanyl load...
# 121 found
#  keyword Select Health Allergy Relief load...
# 0 found
#  keyword Advanced Hand Sanitizer load...
# 0 found
#  keyword THERA RX load...
# 0 found
#  keyword Zoledronic acid load...
# 84 found
#  keyword Raspberry Lip load...
# 0 found
#  keyword butalbital, acetaminophen and caffeine load...
# 1 found
#  keyword AFSTYLA load...
# 3 found
#  keyword equaline antacid load...
# 0 found
#  keyword Aloxi load...
# 15 found
#  keyword Pecan Nut load...
# 7 found
#  keyword 12 Male Reproductive load...
# 0 found
#  keyword Gemfibrozil load...
# 51 found
#  keyword Revlimid load...
# 64 found
#  keyword Testosterone load...
# 107 found
#  keyword Harris Teeter Nasal Allergy load...
# 0 found
#  keyword Chamomilla Belladonna Special Order load...
# 0 found
#  keyword TopCare Sore Throat Cherry Flavor load...
# 0 found
#  keyword DayTime Nighttime load...
# 0 found
#  keyword Fluoxetine load...
# 108 found
#  keyword VASOPRO EPHEDRINE load...
# 0 found
#  keyword Pulmo Echinacea load...
# 0 found
#  keyword Escitalopram Oxalate load...
# 5 found
#  keyword CVS Fragrance Free Anti-Itch load...
# 0 found
#  keyword Sodium Bicarbonate load...
# 70 found
#  keyword Australian Gold load...
# 0 found
#  keyword Midazolam hydrochloride load...
# 3 found
#  keyword Zodryl DEC 80 load...
# 0 found
#  keyword Anticavity Rinse load...
# 0 found
#  keyword Gentle Laxative load...
# 0 found
#  keyword Upset Stomach Relief load...
# 0 found
#  keyword Touchland Power Mist Moisturizing Hand Sanitizer Lavender Scented load...
# 0 found
#  keyword Honeysuckle Ginger Hand Sanitizer load...
# 0 found
#  keyword Haloperidol load...
# 73 found
#  keyword Dr. Dream Urban Protective Advanced BB load...
# 0 found
#  keyword Zolpidem Tartrate load...
# 6 found
#  keyword care one ibuprofen load...
# 0 found
#  keyword Hydroxyzine Pamoate load...
# 0 found
#  keyword FENTANYL load...
# 2 found
#  keyword Walgreens load...
# 42 found
#  keyword Bupropion Hydrochloride load...
# 7 found
#  keyword Neutrogena SkinClearing load...
# 0 found
#  keyword Clolar load...
# 2 found
#  keyword ARTHRITIS PAIN RELIEF load...
# 0 found
#  keyword Magnesium Oxide load...
# 43 found
#  keyword Leader load...
# 62 found
#  keyword Hydrocortisone Plus load...
# 0 found
#  keyword KONSYL Sugar Free Orange Flavor Psyllium Fiber load...
# 0 found
#  keyword MORPHINE SULFATE load...
# 3 found
#  keyword Eastern Cottonwood load...
# 6 found
#  keyword GABAPENTIN load...
# 1 found
#  keyword Cephalexin load...
# 26 found
#  keyword Pain Relief load...
# 71 found
#  keyword HYPERT HP load...
# 0 found
#  keyword BeneFIX load...
# 24 found
#  keyword MUCOR RACEMOSUS load...
# 3 found
#  keyword VAX load...
# 49 found
#  keyword RANITIDINE load...
# 0 found
#  keyword Xrylix load...
# 0 found
#  keyword Antibacterial Hand Wash load...
# 0 found
#  keyword Noble Lion Medicated Balm load...
# 0 found
#  keyword Xylocaine load...
# 22 found
#  keyword Axe load...
# 12 found
#  keyword Aloe Up load...
# 0 found
#  keyword ALPHAGAN P load...
# 1 found
#  keyword Eliphos load...
# 0 found
#  keyword Clearasil load...
# 0 found
#  keyword Osteoarthritica Synergy load...
# 0 found
#  keyword JANUVIA load...
# 4 found
#  keyword Childrens Daytime Cold and Cough load...
# 0 found
#  keyword Medroxyprogesterone Acetate load...
# 43 found
#  keyword laura mercier tinted moisturizer Broad Spectrum SPF 20 Sunscreen Lightweight Flawless Coverage NATURAL load...
# 0 found
#  keyword Crocus sativus load...
# 328 found
#  keyword UltrasolSunscreen load...
# 0 found
#  keyword Ondansetron load...
# 109 found
#  keyword Metoprolol Tartrate load...
# 18 found
#  keyword Antiseptic Mouth Rinse load...
# 0 found
#  keyword Ursodiol load...
# 16 found
#  keyword EXTERNAL ANALGESIC load...
# 2 found
#  keyword LBEL ESSENTIAL Deep moisturizing and oxygenating SPF 20 normal to dry skin load...
# 0 found
#  keyword Valsartan and Hydrochlorothiazide load...
# 6 found
#  keyword Hamamelis virginiana load...
# 104 found
#  keyword Fexofenadine HCl load...
# 24 found
#  keyword Nortriptyline Hydrochloride load...
# 2 found
#  keyword Naproxen load...
# 65 found
#  keyword DIAL FOAMING HAND WASH load...
# 0 found
#  keyword NoSno load...
# 0 found
#  keyword RECOMBINATE load...
# 2 found
#  keyword Methenamine Hippurate load...
# 3 found
#  keyword Good Neighbor Pharmacy Sleep Time load...
# 0 found
#  keyword CLE DE PEAU BEAUTE CR COMPACT FOUNDATION load...
# 0 found
#  keyword Iodine Tincture Rojo load...
# 0 found
#  keyword EstroGel load...
# 1 found
#  keyword Leader Sterile Ultra Lubricating Eye load...
# 0 found
#  keyword Metformin hydrochloride load...
# 38 found
#  keyword Capsicum annuum load...
# 316 found
#  keyword Heparin Sodium load...
# 8 found
#  keyword Select Brand Anti-Itch load...
# 0 found
#  keyword Good Sense Allergy Multi Symptom load...
# 0 found
#  keyword Methylprednisolone Sodium Succinate load...
# 5 found
#  keyword bareMinerals READY Touch Up Veil Broad Spectrum SPF 15 load...
# 0 found
#  keyword PROAIRHFA load...
# 0 found
#  keyword CITALOPRAM HYDROBROMIDE load...
# 17 found
#  keyword Tizanidine load...
# 64 found
#  keyword Gas Relief load...
# 1 found
#  keyword Naropin load...
# 37 found
#  keyword Womens Laxative load...
# 0 found
#  keyword Olopatadine Hydrochloride load...
# 8 found
#  keyword Temozolomide load...
# 98 found
#  keyword Smart Sense ibuprofen load...
# 0 found
#  keyword anti bacterial hand sanitizer load...
# 0 found
#  keyword Clearasil Ultra load...
# 0 found
#  keyword Allergy Relief load...
# 0 found
#  keyword Etoposide load...
# 54 found
#  keyword Potassium Chloride in Dextrose and Sodium Chloride load...
# 0 found
#  keyword Publix UltraDish Detergent Green Apple Scent load...
# 0 found
#  keyword Topiramate load...
# 107 found
#  keyword SERTRALINE HYDROCHLORIDE load...
# 34 found
#  keyword Tag Away load...
# 0 found
#  keyword Menstrual Relief load...
# 0 found
#  keyword Instant Hand Antiseptic load...
# 0 found
#  keyword Algonquin HanClean Foam load...
# 0 found
#  keyword Cicatricure Scar SPF 30 load...
# 0 found
#  keyword Vitamin Deficiency Injectable System - B12 load...
# 0 found
#  keyword Maximum Strength Nasal Decongestant load...
# 0 found
#  keyword Dermazene load...
# 0 found
#  keyword CLINIQUE TARGETED PROTECTION SPF 45 BROAD SPECTRUM SUNSCREEN load...
# 0 found
#  keyword CAPRELSA load...
# 1 found
#  keyword AF Foam Sensitive Acne Pore Cleanser load...
# 0 found
#  keyword Phendimetrazine Tartrate load...
# 0 found
#  keyword Sildenafil load...
# 132 found
#  keyword Rosuvastatin load...
# 124 found
#  keyword Naproxen Sodium load...
# 16 found
#  keyword Topcare Tussin load...
# 0 found
#  keyword topiramate load...
# 180 found
#  keyword ck one waterfresh face makeup spf 15 load...
# 0 found
#  keyword Arnica Apis Nervus trigeminus Special Order load...
# 0 found
#  keyword Black Oak load...
# 4 found
#  keyword Theochem Tea Tree Hand and Body Wash load...
# 0 found
#  keyword CONDURANGO load...
# 1 found
#  keyword Kit for the Preparation of Technetium Tc99m Pyrophosphate load...
# 0 found
#  keyword CareOne nicotine load...
# 0 found
#  keyword ELOCON load...
# 0 found
#  keyword Levemir load...
# 73 found
#  keyword Toviaz load...
# 7 found
#  keyword Extra Moisturizing Nasal Pump Mist load...
# 0 found
#  keyword Dextroamphetamine Sulfate load...
# 0 found
#  keyword Cedar Elm load...
# 0 found
#  keyword Superman Berry Scented Antiseptic Hand Cleansing load...
# 0 found
#  keyword Diovan load...
# 51 found
#  keyword Ibuprofen and Pseudoephedrine hydrochloride load...
# 0 found
#  keyword Sugar Free Honey Lemon Cough Drops load...
# 0 found
#  keyword Spatherapy load...
# 0 found
#  keyword Metaxalone load...
# 25 found
#  keyword Nicotrol load...
# 19 found
#  keyword Pain Relief Cream load...
# 0 found
#  keyword Rizatriptan load...
# 57 found
#  keyword VitaCin load...
# 0 found
#  keyword AcneFree load...
# 0 found
#  keyword Preparation H Rapid Relief load...
# 0 found
#  keyword Milk of Magnesia Original load...
# 0 found
#  keyword Metoprolol Succinate load...
# 14 found
#  keyword ropinirole load...
# 144 found
#  keyword Diaper Rash load...
# 16 found
#  keyword ECZEMA AND PSORIASIS FREE load...
# 0 found
#  keyword Esomeprazole Sodium load...
# 1 found
#  keyword Aveeno Active Naturals Positively Radiant Daily Moisturizer Broad Spectrum SPF15 load...
# 0 found
#  keyword Western Family Itch Relief load...
# 0 found
#  keyword Motion Sickness load...
# 63 found
#  keyword Levothyroxine Sodium load...
# 7 found
#  keyword MAR-COF CG load...
# 0 found
#  keyword TARCEVA load...
# 1 found
#  keyword Cough and Cold HBP load...
# 0 found
#  keyword Veneno de Abeja load...
# 0 found
#  keyword FLUZONE High-Dose load...
# 0 found
#  keyword Jane Seymour Natural Advantage AM SPF 15 All Day Moisture with AHAs load...
# 0 found
#  keyword PERFORM COOL AND SOOTHING PAIN RELIEVING ROLL-ON load...
# 0 found
#  keyword Utah Juniper load...
# 2 found
#  keyword Detrol LA load...
# 3 found
#  keyword Carbaphen Ped CH load...
# 0 found
#  keyword Sebum Clearing Masque load...
# 0 found
#  keyword Papaya load...
# 84 found
#  keyword Goodsense Diaper Rash load...
# 0 found
#  keyword Acetic Acid load...
# 53 found
#  keyword letrozole load...
# 214 found
#  keyword BodyAnew load...
# 0 found
#  keyword Warfarin Sodium load...
# 3 found
#  keyword Memantine hydrochloride load...
# 19 found
#  keyword English Walnut load...
# 10 found
#  keyword ALOE ICE load...
# 0 found
#  keyword PreviDent load...
# 9 found
#  keyword Sugar Maple load...
# 26 found
#  keyword AcneFree Body Clearing load...
# 0 found
#  keyword Pulsatilla load...
# 239 found
#  keyword TRI-LO-MARZIA load...
# 0 found
#  keyword METOPROLOL TARTRATE load...
# 0 found
#  keyword Fresh Cucumber Classic Body load...
# 0 found
#  keyword Ciprofloxacin Hydrochloride load...
# 10 found
#  keyword Cefaclor load...
# 19 found
#  keyword Zonisamide load...
# 60 found
#  keyword Honey Lemon Cough Drop load...
# 0 found
#  keyword Baby Face and Body Creamy load...
# 0 found
#  keyword Witch Hazel load...
# 18 found
#  keyword ParaClenz load...
# 0 found
#  keyword Potassium Chloride load...
# 28 found
#  keyword Avenoc load...
# 0 found
#  keyword Alendronate Sodium load...
# 11 found
#  keyword Quazepam load...
# 39 found
#  keyword D-118 load...
# 0 found
#  keyword Pepperment Cough Drops load...
# 0 found
#  keyword Polyethylene Glycol-3350 and Electrolytes with Flavor Pack load...
# 0 found
#  keyword HYDROCODONE BITARTRATE AND ACETAMINOPHEN load...
# 0 found
#  keyword Loperamide Hydrochloride load...
# 2 found
#  keyword Alcohol Cleansing Pad load...
# 0 found
#  keyword Mamonde Brightening Cover Watery Cushion No. 37 load...
# 0 found
#  keyword Burn Relief load...
# 0 found
#  keyword FEXOFENADINE HYDROCHLORIDE load...
# 29 found
#  keyword Vicks DayQuil load...
# 1 found
#  keyword Gnarly Head SPF 30 load...
# 0 found
#  keyword Epsom Salt load...
# 2 found
#  keyword LE TECHNIQ load...
# 0 found
#  keyword Mydriatic-4 load...
# 0 found
#  keyword Pioglitazone load...
# 134 found
#  keyword Help I cant Sleep load...
# 0 found
#  keyword Ruta Graveolens load...
# 6 found
#  keyword Instant Hand Sanitizer TENNder CARE load...
# 0 found
#  keyword EPINEPHRINE load...
# 1 found
#  keyword Mometasone Furoate load...
# 33 found
#  keyword Soleil Broad Spectrum SPF-15 load...
# 0 found
#  keyword Mucinex Fast Max load...
# 0 found
#  keyword Dove load...
# 10 found
#  keyword Celecoxib load...
# 116 found
#  keyword BabyGanics Alcohol Free Foaming Hand Sanitizer load...
# 0 found
#  keyword PCXX MINUTE FM LIME load...
# 0 found
#  keyword Pyridostigmine Bromide load...
# 2 found
#  keyword Megestrol Acetate load...
# 16 found
#  keyword Liver Tonic load...
# 0 found
#  keyword No7 Lift and Luminate Triple Action Serum Foundation Sunscreen Broad Spectrum SPF 15 Toffee load...
# 0 found
#  keyword REMEDI Health Solutions load...
# 0 found
#  keyword All Day Allergy load...
# 0 found
#  keyword Ziprasidone load...
# 60 found
#  keyword Ionite APF load...
# 0 found
#  keyword CVS Health load...
# 7 found
#  keyword EDECRIN load...
# 0 found
#  keyword Levetiracetam load...
# 104 found
#  keyword Amantadine Hydrochloride load...
# 3 found
#  keyword 3CE DRAWING LIP YOU GOT ME load...
# 0 found
#  keyword Inflammation load...
# 66 found
#  keyword Colace Clear load...
# 0 found
#  keyword TISSEEL load...
# 20 found
#  keyword matte full cover foundation C43 load...
# 0 found
#  keyword Clorox Antibacterial Hand - Cherry and Magnolia Blossom load...
# 0 found
#  keyword Stramonium load...
# 9 found
#  keyword Childrens Acetaminophen load...
# 0 found
#  keyword Zolmitriptan load...
# 53 found
#  keyword Full Hair Solution load...
# 0 found
#  keyword SAINT External Pain Relieving Bandage load...
# 0 found
#  keyword SHISEIDO PERFECT REFINING FOUNDATION load...
# 0 found
#  keyword Synthroid load...
# 34 found
#  keyword Dr. Perrys Day Thyme SPF 20 Broad Spectrum Sunscreen load...
# 0 found
#  keyword Phenylephrine HCl load...
# 3 found
#  keyword Cefdinir load...
# 25 found
#  keyword MethylPREDNISolone load...
# 0 found
#  keyword clarithromycin load...
# 216 found
#  keyword Timolol Maleate load...
# 36 found
#  keyword HAND SANITIZER load...
# 20 found
#  keyword omeprazole load...
# 205 found
#  keyword Pollens - Trees, Birch Mix load...
# 0 found
#  keyword methazolamide load...
# 123 found
#  keyword SnugZ Hand Sanitizer Gel load...
# 0 found
#  keyword LANOXIN load...
# 0 found
#  keyword Benazepril Hydrochloride load...
# 6 found
#  keyword MEMBERS SELECTION ANTIBACTERIAL load...
# 0 found
#  keyword MILK OF MAGNESIA ORIGINAL load...
# 0 found
#  keyword Treatment Set TS340153 load...
# 0 found
#  keyword Theraworx Relief load...
# 0 found
#  keyword Long Last Makeup 03 load...
# 0 found
#  keyword INSTANT HAND SANITIZER load...
# 0 found
#  keyword Articulatio genus 8 load...
# 0 found
#  keyword GRAPHITES load...
# 0 found
#  keyword Inflammatory Terrain load...
# 0 found
#  keyword Buspirone Hydrochloride load...
# 3 found
#  keyword Instant Ear Dry load...
# 0 found
#  keyword All Day Relief load...
# 0 found
#  keyword Cellular Radiance Emulsion SPF 30 load...
# 0 found
#  keyword BIRDS GARDEN LIP BALM load...
# 0 found
#  keyword MAXRELIEF load...
# 0 found
#  keyword Paroxetine load...
# 73 found
#  keyword CitraNatal DHA load...
# 0 found
#  keyword Antispetic load...
# 0 found
#  keyword Zcaine Fast Acting Anesthetic load...
# 0 found
#  keyword Dial Antibacterial Hand Wash load...
# 0 found
#  keyword Foaming Instant Hand Sanitizer with Aloe load...
# 0 found
#  keyword Nu Skin Nu Colour advanced tinted moisturizer broad spectrum SPF 15 - Sand load...
# 0 found
#  keyword Mastic Dent Whitening load...
# 0 found
#  keyword JAYJUN ANTI DUST BRIGHTENING MASK 03 JAYJUN ANTI DUST EYES UNDER CORRECTOR load...
# 0 found
#  keyword Neuro load...
# 85 found
#  keyword EVERYDAY SUNSCREEN SPF 50 with Sunflower Extract load...
# 0 found
#  keyword Extra Strength Acetaminophen load...
# 0 found
#  keyword Flexall Pain Relieving load...
# 0 found
#  keyword Pelo Baum Lash Lash load...
# 0 found
#  keyword AuroFlu Night Time Severe Cold and Cough Warming Relief load...
# 0 found
#  keyword Triple Antibiotic load...
# 26 found
#  keyword C Mold Mixture load...
# 0 found
#  keyword Glipizide and Metformin HCl load...
# 0 found
#  keyword core values childrens ibuprofen load...
# 0 found
#  keyword Clinpro 5000 load...
# 5 found
#  keyword Lidocaine Viscous load...
# 0 found
#  keyword Thyroid Tonic load...
# 0 found
#  keyword Bio Chem Detox load...
# 0 found
#  keyword Fenoprofen Calcium load...
# 3 found
#  keyword Ginseng Khan load...
# 0 found
#  keyword NP THYROID 60 load...
# 0 found
#  keyword Dr. Dream Advanced Facial Treatment Serum load...
# 0 found
#  keyword LEVOTHYROXINE SODIUM load...
# 17 found
#  keyword BENEFIT HELLO FLAWLESS OXYGEN WOW Broad Spectrum SPF 25 BRIGHTENING MAKEUP - IM PURE 4 SURE load...
# 0 found
#  keyword ADVIL PM load...
# 0 found
#  keyword Prazosin Hydrochloride load...
# 0 found
#  keyword SHISEIDO URBAN ENVIRONMENT load...
# 0 found
#  keyword EFFEXOR load...
# 0 found
#  keyword DVORAH load...
# 0 found
#  keyword Fluocinonide load...
# 13 found
#  keyword Little Ouchies Little Remedies Pain Relief load...
# 0 found
#  keyword health care personnel handwash load...
# 6 found
#  keyword Spironolactone load...
# 88 found
#  keyword Calc Fluor load...
# 0 found
#  keyword Vizimpro load...
# 1 found
#  keyword Perphenazine load...
# 24 found
#  keyword Quillivant load...
# 5 found
#  keyword Cherry cough drop load...
# 0 found
#  keyword Aspirin load...
# 158 found
#  keyword Childrens Plus Multi Symptom Cold load...
# 0 found
#  keyword Valproic load...
# 112 found
#  keyword LBEL DERMO CLARITE BRIGHTENING AND MOISTURIZING FACIAL SPF 30 load...
# 0 found
#  keyword KETOROLAC TROMETHAMINE load...
# 13 found
#  keyword Desipramine Hydrochloride load...
# 0 found
#  keyword Antibacterial load...
# 101 found
#  keyword buspirone hydrochloride load...
# 67 found
#  keyword Lisinopril and Hydrochlorothiazide load...
# 1 found
#  keyword E-Z-HD load...
# 0 found
#  keyword Atorvastatin Calcium load...
# 16 found
#  keyword Mucus Relief load...
# 0 found
#  keyword Teriflunomide load...
# 90 found
#  keyword HYDROCORTISONE VALERATE load...
# 0 found
#  keyword Esmolol Hydrochloride load...
# 2 found
#  keyword Clearasil Stubborn Acne Control 5in1 Spot Treatment load...
# 0 found
#  keyword Meropenem load...
# 105 found
#  keyword Ultimate Sheer SPF 70 load...
# 0 found
#  keyword Fluconazole load...
# 75 found
#  keyword Relaxing Leg Homeopathic load...
# 0 found
#  keyword Hendel Nerve Pain Relief load...
# 0 found
#  keyword Omeprazole load...
# 80 found
#  keyword Thursday Plantation load...
# 0 found
#  keyword ASTRAPHARM CHILLI BRAND EXTERNAL MEDICATED load...
# 0 found
#  keyword Nicorette load...
# 77 found
#  keyword CLOMIPRAMINE HYDROCHLORIDE load...
# 0 found
#  keyword ACER RUBRUM POLLEN load...
# 0 found
#  keyword G-5 load...
# 3 found
#  keyword cold relief load...
# 4 found
#  keyword Omnaris load...
# 0 found
#  keyword Klor-Con Sprinkle load...
# 0 found
#  keyword Clonazepam load...
# 38 found
#  keyword Alertness Aid Stay Awake load...
# 0 found
#  keyword Pro-Den Rx load...
# 0 found
#  keyword Venlafaxine Hydrochloride load...
# 11 found
#  keyword NEVIRAPINE load...
# 0 found
#  keyword Atenolol load...
# 48 found
#  keyword Oxygen, Compressed load...
# 0 found
#  keyword equaline naproxen sodium load...
# 0 found
#  keyword Detox load...
# 36 found
#  keyword Jet Lag and Shift Change load...
# 0 found
#  keyword Tussin Peak Cold Cough plus Chest Congestion DM load...
# 0 found
#  keyword RISPERIDONE load...
# 1 found
#  keyword Unithroid load...
# 3 found
#  keyword GERM FREE 24 PLUS load...
# 0 found
#  keyword Dynamic Eyewash load...
# 0 found
#  keyword Methotrexate load...
# 119 found
#  keyword Prednisone load...
# 19 found
#  keyword Trandolapril load...
# 59 found
#  keyword daytime nighttime cold and flu load...
# 0 found
#  keyword Equate Nicotine load...
# 0 found
#  keyword Metoclopramide load...
# 67 found
#  keyword Inspra load...
# 35 found
#  keyword Tiege Hanley AM Morning Facial Moisturizer with SPF20 load...
# 0 found
#  keyword Givenchy Photo Perfexion Fluid Foundation SPF 20 Perfect Suede Tint 6.5 load...
# 0 found
#  keyword Ceftriaxone Sodium load...
# 6 found
#  keyword XIFAXAN load...
# 0 found
#  keyword Standardized Grass Pollen, Fescue, Meadow load...
# 0 found
#  keyword Zap APF load...
# 0 found
#  keyword Phenazopyridine Hydrochloride load...
# 1 found
#  keyword Reed Canary Grass load...
# 2 found
#  keyword Piperacillin and Tazobactam load...
# 3 found
#  keyword SUPER ORIGIN COTTON FINISH FOUNDATION load...
# 0 found
#  keyword CVS Health Muscle Rub load...
# 0 found
#  keyword AHIST load...
# 0 found
#  keyword Pain and Fever load...
# 8 found
#  keyword SUPER DEFENSE load...
# 0 found
#  keyword Hyalucollagen Moisture load...
# 0 found
#  keyword Liver Boost load...
# 0 found
#  keyword Justice Pineapple Scent Anti-Bacterial Hand Sanitizer load...
# 0 found
#  keyword Miracle Heel Repair load...
# 0 found
#  keyword Cepacol load...
# 28 found
#  keyword HILLYARD NT Peach Antimicrobial Foam Cleanser load...
# 0 found
#  keyword Neomycin Polymyxin B Sulfates and Dexamethasone load...
# 0 found
#  keyword meloxicam load...
# 237 found
#  keyword ASPIRIN load...
# 2 found
#  keyword Redness reliever load...
# 0 found
#  keyword Mineral Sunscreen Lip Balm SPF 15 load...
# 0 found
#  keyword Betamethasone Valerate load...
# 13 found
#  keyword Ignatia Bryophyllum load...
# 0 found
#  keyword Royal Petroleum (Cocoa Scent) load...
# 0 found
#  keyword Diclofenac Sodium load...
# 44 found
#  keyword ANACARDIUM ORIENTALE load...
# 0 found
#  keyword Nighttime Sleep-Aid load...
# 0 found
#  keyword up and up cough plus chest congestion load...
# 0 found
#  keyword Tolnafate load...
# 0 found
#  keyword Multi Symptom Cold CF load...
# 0 found
#  keyword Doxazosin Mesylate load...
# 8 found
#  keyword Nabumetone load...
# 34 found
#  keyword Alprazolam load...
# 42 found
#  keyword Furosemide load...
# 79 found
#  keyword Lady Speed Stick load...
# 0 found
#  keyword Motion Sickness Relief load...
# 0 found
#  keyword VENLAFAXINE HYDROCHLORIDE load...
# 60 found
#  keyword OXYGEN load...
# 0 found
#  keyword Prolongz load...
# 0 found
#  keyword Aplenzin load...
# 0 found
#  keyword Campho-Phenique load...
# 4 found
#  keyword fine finish pressed powder C13 load...
# 0 found
#  keyword YOUTHTOPIA SKIN FIRMING FOUNDATION load...
# 0 found
#  keyword Povidone-Iodine Solution load...
# 5 found
#  keyword HEMOFIL M load...
# 0 found
#  keyword 2-Pack Hand Sanitizer load...
# 0 found
#  keyword Cold-EEZE load...
# 0 found
#  keyword Cold and Flu load...
# 5 found
#  keyword Disney princess 4pack Hand Sanitizer load...
# 0 found
#  keyword POVIDONE-IODINE PREP load...
# 0 found
#  keyword Eucalyptus load...
# 285 found
#  keyword McKesson Alcohol Prep Pad load...
# 0 found
#  keyword Duloxetine load...
# 94 found
#  keyword Seaweed Oil-Control SPF 15 load...
# 0 found
#  keyword Divalproex Sodium load...
# 8 found
#  keyword Chromium oxydatum load...
# 0 found
#  keyword Ferrum phosphoricum load...
# 5 found
#  keyword Nitrogen load...
# 107 found
#  keyword 3CE LIP LACQUER HAWAIIAN PINK load...
# 0 found
#  keyword Le Vital Japanese Cherry Blossom load...
# 0 found
#  keyword ESIKA PRO PERFECT MATCH VOLUMEN load...
# 0 found
#  keyword antacid load...
# 176 found
#  keyword Equate Anti-Wrinkle load...
# 0 found
#  keyword fenofibric acid load...
# 247 found
#  keyword Ipratropium Bromide load...
# 10 found
#  keyword Exchange Select Ibuprofen PM load...
# 0 found
#  keyword West Wheat Grass load...
# 0 found
#  keyword Oxygen load...
# 99 found
#  keyword Shaklee Essentials Desert Wind Roll-On Antiperspirant load...
# 0 found
#  keyword Back and Neck Rescue load...
# 0 found
#  keyword Goodys Headache Relief Shot load...
# 0 found
#  keyword Valeriana Officinalis load...
# 1 found
#  keyword O24 Pain Neutralizer load...
# 0 found
#  keyword Ropivacaine Hydrochloride load...
# 4 found
#  keyword olanzapine load...
# 219 found
#  keyword ZONISAMIDE load...
# 0 found
#  keyword Lubricant Eye Drops Preservative Free load...
# 0 found
#  keyword Encare load...
# 9 found
#  keyword SkinSaver Polygonum Multi Purpose load...
# 0 found
#  keyword Naturasil load...
# 0 found
#  keyword URSODIOL load...
# 2 found
#  keyword Lenscale Quailbrush load...
# 0 found
#  keyword Jasmine Rose Hand Wash Nettoyant Pour Les Mains load...
# 0 found
#  keyword CASEIN load...
# 1 found
#  keyword Novita Petrolatum Jelly Pink load...
# 0 found
#  keyword No7 Beautifully Matte Foundation Sunscreen Broad Spectrum SPF 15 Wheat load...
# 0 found
#  keyword HYDROXYZINE PAMOATE load...
# 1 found
#  keyword Norpace load...
# 52 found
#  keyword CVS Foaming Hand Sanitizer load...
# 0 found
#  keyword Delsym load...
# 0 found
#  keyword Propafenone HCl load...
# 3 found
#  keyword Revlon Mitchum Clinical Gel load...
# 0 found
#  keyword LBEL COULEUR LUXE AMPLIFIER XP load...
# 0 found
#  keyword Tolazamide load...
# 13 found
#  keyword Petrolatum load...
# 17 found
#  keyword Ambien CR load...
# 6 found
#  keyword Core Values Omeprazole load...
# 0 found
#  keyword Gelsemium Bryonia load...
# 0 found
#  keyword ProBLEN Libido load...
# 0 found
#  keyword Dexmethylphenidate Hydrochloride load...
# 0 found
#  keyword methylphenidate hydrochloride load...
# 70 found
#  keyword extra strength foot care liquid gel load...
# 0 found
#  keyword Anti-Bacterial Hand load...
# 0 found
#  keyword Oxcarbazepine load...
# 64 found
#  keyword VERY VANILLA SCENTED HAND SANITIZER load...
# 0 found
#  keyword Labetalol hydrochloride load...
# 8 found
#  keyword Gallbladder Dr. load...
# 0 found
#  keyword Childrens Cold and Allergy load...
# 0 found
#  keyword LBEL EFFET PARFAIT Spots Reducing Effect Foundation SPF 18 - OBSCURE 8B load...
# 0 found
#  keyword HYDROCORTISONE IODOQUINOL load...
# 0 found
#  keyword 06 Moisture Foundation SPF 15 load...
# 0 found
#  keyword Circle K Pain Reliever load...
# 0 found
#  keyword Hydroxyzine Hydrochloride load...
# 1 found
#  keyword Lander load...
# 8 found
#  keyword BAMBOO SALT Eunganggo Jook Yeom load...
# 0 found
#  keyword NYLOXIN load...
# 0 found
#  keyword REGENECARE HA load...
# 0 found
#  keyword MUCINEX Childrens Stuffy Nose load...
# 0 found
#  keyword AnXious load...
# 0 found
#  keyword Lovastatin load...
# 74 found
#  keyword Colgate Enamel Health Mineral Repair load...
# 0 found
#  keyword Soft Care Antiseptic Skin Cleanser load...
# 0 found
#  keyword ZERIT load...
# 1 found
#  keyword Amoxicillin and Clavulanate Potassium load...
# 1 found
#  keyword Nu Skin Nu Colour advanced finish broad spectrum SPF 15 - Tawny load...
# 0 found
#  keyword Neova DNA Damage Control - Everyday load...
# 0 found
#  keyword Truly Radiant Bright and Strong load...
# 0 found
#  keyword LBEL NATURAL FINISH MOISTURIZING FOUNDATION SPF 25 load...
# 0 found
#  keyword Nicotac Nicotine Polacrilex load...
# 0 found
#  keyword Wormwood load...
# 12 found
#  keyword Selenium Sulfide load...
# 1 found
#  keyword Felbamate load...
# 24 found
#  keyword voriconazole load...
# 226 found
#  keyword Nevi (Mole) Control load...
# 0 found
#  keyword CTx4 Rinse load...
# 0 found
#  keyword Native Tan SPF 50 load...
# 0 found
#  keyword Handtastic Foamy Mango load...
# 0 found
#  keyword clonidine hydrochloride load...
# 71 found
#  keyword anti-bacterial hand gel load...
# 0 found
#  keyword Alcohol load...
# 166 found
#  keyword Methylergonovine Maleate load...
# 0 found
#  keyword Childrens Mucinex Stuffy Nose and Cold load...
# 0 found
#  keyword hyoscyamine sulfate load...
# 25 found
#  keyword Depo-Medrol load...
# 93 found
#  keyword SUBVENITE load...
# 0 found
#  keyword Triaminic load...
# 6 found
#  keyword Neomycin and Polymyxin B Sulfates and Gramicidin load...
# 0 found
#  keyword dg health cold and flu relief load...
# 0 found
#  keyword Miconazole Nitrate load...
# 16 found
#  keyword Topex load...
# 23 found
#  keyword DIAZEPAM load...
# 0 found
#  keyword MUSE load...
# 42 found
#  keyword Digoxin load...
# 107 found
#  keyword BOTANICAL GREEN TEA PORE BB load...
# 0 found
#  keyword Kinesys load...
# 0 found
#  keyword RHUBARB load...
# 0 found
#  keyword members mark lansoprazole load...
# 0 found
#  keyword Cyclobenzaprine Hydrochloride load...
# 3 found
#  keyword leader infants ibuprofen load...
# 0 found
#  keyword propafenone hydrochloride load...
# 50 found
#  keyword Amoxicillin load...
# 55 found
#  keyword Methocarbamol load...
# 40 found
#  keyword Urban Decay Naked Skin Light Beauty Balm SPF20 load...
# 0 found
#  keyword To Save Face SPF 30 Plus load...
# 0 found
#  keyword CLADOSPORIUM CLADOSPORIOIDES load...
# 0 found
#  keyword Duck Meat load...
# 9 found
#  keyword ROPINIROLE HYDROCHLORIDE load...
# 10 found
#  keyword Humalog load...
# 76 found
#  keyword Etodolac load...
# 57 found
#  keyword desonide load...
# 89 found
#  keyword Crest Pro-Health Advanced load...
# 0 found
#  keyword Tobacco Withdrawal load...
# 8 found
#  keyword Pretty by Flormar BB 002 Light Medium load...
# 0 found
#  keyword D-100 load...
# 5 found
#  keyword Thyrostat load...
# 0 found
#  keyword Ear Wax Removal Drops load...
# 1 found
#  keyword Spatherapy Eucalyptus Mint load...
# 0 found
#  keyword Kids Sore Throat Relief load...
# 0 found
#  keyword Ropinirole Hydrochloride load...
# 2 found
#  keyword Atovaquone and Proguanil Hydrochloride load...
# 0 found
#  keyword Veratrum Alb load...
# 0 found
#  keyword Western Ragweed load...
# 2 found
#  keyword AcetaZOLAMIDE load...
# 0 found
#  keyword MEROPENEM load...
# 0 found
#  keyword Aveeno Baby Continuous Protection load...
# 0 found
#  keyword 7 Standardized Grass Pollen Mix load...
# 0 found
#  keyword Mucus Relief Severe Sinus Congestion load...
# 0 found
#  keyword Fentanyl Citrate load...
# 8 found
#  keyword Good Neighbor pharmacy muscle rub load...
# 0 found
#  keyword GOCOVRI load...
# 3 found
#  keyword Dextroamphetamine Saccharate, Amphetamine Aspartate, Dextroamphetamine Sulfate, and Amphetamine Sulfate load...
# 0 found
#  keyword Erythromycin load...
# 57 found
#  keyword CRYSTAL MIRACLE MULTI load...
# 0 found
#  keyword Berry Scented Hand Sanitizer load...
# 0 found
#  keyword Actoplus Met load...
# 1 found
#  keyword Glofil-125 load...
# 3 found
#  keyword BENALDRYL load...
# 0 found
#  keyword Hillyard Alcohol Free Foaming Instant Hand Sanitizer load...
# 0 found
#  keyword UltraCare load...
# 4 found
#  keyword TERBINAFINE HYDROCHLORIDE load...
# 13 found
#  keyword Vesen Antiperpirant Deodorant Roll-On load...
# 0 found
#  keyword Illuminating Daily Moisturizer load...
# 0 found
#  keyword Cold Sores and Fever Blisters load...
# 0 found
#  keyword Burberry Fresh Glow Foundation Luminous Fluid Warm Honey No. 38 load...
# 0 found
#  keyword Benzalkonium Chloride load...
# 42 found
#  keyword Ecotrin load...
# 7 found
#  keyword Azacitidine load...
# 72 found
#  keyword Helleborus niger 6 load...
