# %% [markdown]
# # Load model

# %%
from flair.data import Sentence
from flair.models import SequenceTagger

# load the NER tagger
model_output_folder = 'twimed-ner-bert'
tagger = SequenceTagger.load_from_file(model_output_folder + '/final-model.pt')

def predict(tagger, text):
    print('===============================================')
    text = text.replace('#', '')
    sentence = Sentence(text)
    tagger.predict(sentence)
    print(sentence)
    print('--------------------------------')

    # iterate over entities and print
    for entity in sentence.get_spans('ner'):
        print(entity)
# Out:
# 2019-03-21 10:58:44,302 loading file twimed-ner-bert/final-model.pt

# %%
#
predict(tagger, """Starting back on fluoxetine tonight, I did pick up the prescription a few days ago but in the past when I’ve started/upped meds I’ve had to call in sick to work due to side effects. So I waited. Now I have 3 days off to adjust""")
# Out:
# ===============================================
# Sentence: "Starting back on fluoxetine tonight, I did pick up the prescription a few days ago but in the past when I’ve started/upped meds I’ve had to call in sick to work due to side effects. So I waited. Now I have 3 days off to adjust" - 46 Tokens
# --------------------------------
# Drug-span [4]: "fluoxetine"
# DATE-span [13,14]: "few days"
# DATE-span [42,43]: "3 days"

# %%
from twitterscraper import query_tweets

class TwitterWatch: 
    def __init__(self, tagger):
        self.tagger = tagger
        
    def query(self, product):
        list_of_tweets = query_tweets(product, 100, lang='en')
        for tweet in list_of_tweets:            
            source_entity = self.getSourceEntity(tweet.fullname)            
            sentence = self.predict(tweet.text)
            tweet.text_entities = self.getEntityTags(sentence)
            tweet.source_entity = source_entity
            tweet.hasDrug = 'Drug' in tweet.text_entities
            tweet.hasSymptom = 'Disease_Symptom' in tweet.text_entities
            tweet.product = product
        return list_of_tweets
        
    def detect(self, sourcename, text):
        sentence = self.predict(text)        
        text_entities = self.getEntityTags(sentence)        
        hasDrug = 'Drug' in text_entities
        hasSymptom = 'Disease_Symptom' in text_entities        
        return {
            'Name'          : sourcename, 
            'SourceEntity'  : self.getSourceEntity(sourcename), 
            'TextEntity'    : text_entities,
            'Text'          : text, 
            'hasDrug'       : 'Drug' in text_entities,
            'hasSymptom'    : 'Disease_Symptom' in text_entities,
            'entities'      : sentence.to_dict(tag_type='ner'),
            'sentence'      : sentence
        }
        
    
    def getSourceEntity(self, name):
        result = 'UNKNOWN'
        sentence = self.predict(name)        
        for entity in sentence.get_spans('ner'):
            result = entity.tag
        return result
    
    def getEntityTags(self, sentence):
        if(sentence == None):
            return []
        else:
            return list(map( lambda entity: entity.tag, sentence.get_spans('ner') ))
        
    def predict(self, text):
        text = self.cleanTwitterTag(text)
        sentence = Sentence(text)
        self.tagger.predict(sentence)
        return sentence
    
    def cleanTwitterTag(self, text):
        text = text.replace('#', '').replace("@", '')
        return text

# %%
import pandas as pd

def getTwitter(tagger, product):
    tw = TwitterWatch(tagger)
    tweets = tw.query(product);
    tweetsdict = list(map(lambda t: 
    {
        'Product'       : t.product,
        'Name'          : t.fullname, 
        'SourceEntity'  : t.source_entity, 
        'TextEntity'    : t.text_entities,
        'Text'          : t.text, 
        'hasDrug'       : t.hasDrug,
        'hasSymptom'    : t.hasSymptom
    }, tweets))
    df = pd.DataFrame.from_dict(tweetsdict)
    df = df[['Product', 'Name', 'SourceEntity', 'TextEntity', 'hasDrug', 'hasSymptom', 'Text']]
    df = df.sort_values(['SourceEntity', 'hasDrug', 'hasSymptom'])
    return df
    #df.to_excel(f"output_{product}.xlsx")

# %%
from requests import request
import json
from pandas.io.json import json_normalize
def getAdverseEvents(limit):
    adverseEventUrl=f"""https://api.fda.gov/drug/event.json?search=patient.drug.openfda.pharm_class_epc:"drug"&count=patient.drug.medicinalproduct.exact&limit={limit}"""
    response=request(url=adverseEventUrl, method='get')
    ae = response.json()
    return pd.DataFrame(ae['results'])

# %%
outputfile = "TopAdversaryDrugs.xlsx"
ae = getAdverseEvents(200)
top100AdversaryDrug = pd.DataFrame(ae['results'])
top100AdversaryDrug

# %%
count = len(top100AdversaryDrug)
tweetsDF = []
for i, product in enumerate(top100AdversaryDrug['term']):
    clear_output(wait=True)       
    print(product, " (", i+1, "/", count, ") ..." )
    df = getTwitter(tagger, product)
    tweetsDF.append(df)
    clear_output(wait=True)       
result = pd.concat(tweetsDF)
result.to_excel(outputfile)
# Out:
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://www.nytimes.com/2018/01/06/business/humira-drug-prices.html …%20The%20price%20of%20Humira,%20an%20anti-inflammatory%20drug%20dispensed%20in%20an%20injectable%20pen,%20has%20risen%20from%20about%20$19,000%20a%20year%20in%202012,%20to%20more%20than%20$38,000%20today,%20per%20patient,%20after%20rebates,%20according%20to%20SSR%20Health,%20a%20research%20firm.%20That’s%20an%20increase%20of%20100%20percent.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://ift.tt/2um3QJe
# ' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://www.totallyxenca.com %20can%20help%20provide%20your%20body%20with%20Vitamin%20D3%20to%20help%20ward%20off%20many%20health%20risks%20including:%20Osteoporosis,%20Rickets,%20High%20Blood%20Pressure,%20Tuberculosis,%20Cancer%20(Breast,%20Colon%20&%20Prostate)%20Periodontal%20Disease%20' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://truthman30.wordpress.com/2017/11/25/conflicts-of-interest-revolving-doors-and-the-british-lords-and-peers-with-shares-in-gsk-and-other-pharmaceutical-companies/ …%20Please%20RT%20...%20How%20GSK%20influences%20the%20heart%20of%20government%20in%20the%20UK...%20and%20in%20the%20process%20puts%20you%20and%20me%20at%20risk%20of%20dodgy%20drugs%20like%20Seroxat,%20Avandia,%20Pandemrix,%20and%20Cervarix,' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://www.ukpharmacymeds.com/medication/diabetes/competact …
# The%20diabetes%20drug%20Avandia,%20also%20known%20as%20rosiglitazone,%20has%20been%20suspended%20by%20UK%20and%20European%20drug%20watchdogs.%20The%20drug,%20which%20is%20used%20to%20control%20blood%20sugar%20in%20type%202%20diabetes,%20has%20been%20linked%20to%20an%20increased%20risk%20of%20heart%20attack%20and%20stroke%20pic.twitter.com/9E8KzRNZuy' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://www.oldapostoliclutheranchurch.org %20' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://amp.cnn.com/cnn/2019/03/18/health/astronauts-spaceflight-herpes-study/index.html …%20We're%20way%20out%20on%20the%20farm%20here.%20Skip%20the%20acyclovir%20&%20take%20a%20cup%20to%20coffee%20to%20soothe%20your%20cold%20sores.%20We%20don't%20need%20the%20whole%20HIV+AIDS%20antiviral%20cocktail%20for%20an%20awkward%20teenage%20kiss.%20I'm%20sorry,%20but%20it's%20time%20to%20go%20for%20the%20shotgun%20on%20that%20medical%20quackery.' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://jamanetwork.com/journals/jamainternalmedicine/fullarticle/217193 …
# %22Compared%20with%20usual%20care,%20open-label%20pravastatin%20use%20(40%20mg/d)%20did%20not%20reduce%20all-cause%20mortality%20or%20CHD%20mortality%20plus%20nonfatal%20MI%20in%20patients%20with%20(n%20=%201475)%20or%20without%20(n%20=%208880)%20CHD.%20There%20was%20no%20reduction%20in%20all-cause%20mortality...%22' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://ift.tt/2NB9Rtu %20Fundamental%20study%20of%20the%20ultrasonic%20induced%20degradation%20of%20the%20popular%20antihistamine,%20diphenhydramine%20(DPH)%20%20
# Publication%20date:%201%20November%202018
#
# Source:%20Water%20Research,%20Volume%20144
#
# Author(s):%20Danni%20Cui,%20Alexander%20M.%20Mebel,%20Luis%20E.%20Arroyo-Mora,%20Cen%20Zhao,%20…' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://startist.ning.com/forum/topics/buy-salmeterol-online-purchase-salmeterol-no-prescription-cheap …%20advair%20addiction%20fluticasone%20salmeterol%20so%20purchase%20salmeterol%20%20online%20pills%20fast%20greece%20with%20advair%20hfa%20dosage%20salmete' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://CNN.com %20-%20Documents:%20Prozac use%20reports%20more%20likely%20to%20list%20suicide%20-%20Jan%204,%202005
# http://edition.cnn.com/2005/HEALTH/01/04/prozac.documents/ …%20%22One%20of%20the%20documents%20cites%20what%20a%20Lilly%20official%20told%20CNN%20were%2014,198%20adverse-effect%20reports%20in%20which%203.7%20were%20suicide%20attempts%20by%20people%20on%20fluoxetine...%22' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'https://www.nih.gov/news-events/news-releases/studies-indicate-losartan-may-be-effective-treatment-option-marfan-syndrome …%20%20My%20family%20has%20dealt%20with%20this%20for%20YEARS...So%20far%20with%20myself%20and%20my%20son,%20cozaar%20has%20helped%20immensely!' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://Www.ToprolSettlement.com %20-%20AstraZeneca%20Toprol%20XL%20Class%20Action%20Lawsuit%20Settlement%20http://www.hubsly.com/www-toprolsettlement-com-astrazeneca-toprol-xl-class-action-lawsuit-settlement/?utm_source=ReviveOldPost&utm_medium=social&utm_campaign=ReviveOldPost …' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))
# /home/vtssogari/anaconda3/lib/python3.7/site-packages/xlsxwriter/worksheet.py:912: UserWarning: Ignoring URL 'http://i.imgur.com/gugNs9c.jpg %20I%20started%20my%20weight%20loss%20journey%20on%20November%2030th,%202017.%20I%20cut%20down%20to%201500cal%20or%20less%20per%20day,%20with%20the%20help%20of%20Phentermine%20and%20Topamax.%20After%20taking%20them%20for%205%20months,%20I%20lost%20the%20last%205%20pounds%20on%20my%20own%20and%20I’ve%20http://rspec.io/r/914aet6172990 ' with link or location/anchor > 255 characters since it exceeds Excel's limit for URLS
#   force_unicode(url))

# %%
result.to_csv("TopAdversaryDrugs.csv")

# %%
import pandas as pd
df = pd.read_excel(outputfile)

# %%
total_drug = len(df.Product.unique())
total_tweets = len(df)

print(f"Total Drug Count: {total_drug}")
print(f"Total Tweets: {total_tweets}")
# Out:
# Total Drug Count: 200
# Total Tweets: 69626

# %% [markdown]
# ### Many of them is advertisement or drug news tweets
# ### We are interested in personal tweets for drug side effects

# %%
df.head(20)
# Out:
#      Product                            Name SourceEntity  \
# 161  ASPIRIN  JENNY TALIA from Australia  🇦🇺          GPE
# 35   ASPIRIN            ☃️ The Hornbread  ❄️          ORG
# 315  ASPIRIN            Gargamel is my bitch          ORG
# 2    ASPIRIN               Charlotte Pollard       PERSON
# 5    ASPIRIN                    Nabil Kilany       PERSON
# 8    ASPIRIN                  Richard Thomas       PERSON
# 10   ASPIRIN                  Nati Baquerizo       PERSON
# 11   ASPIRIN                    Trisha Blish       PERSON
# 19   ASPIRIN                     Greg McLeod       PERSON
# 20   ASPIRIN                     Lloyd Smith       PERSON
# 26   ASPIRIN                     Katt  🧚🏽‍♀️       PERSON
# 30   ASPIRIN                  Mikey says hey       PERSON
# 36   ASPIRIN                   Louisa Thomas       PERSON
# 45   ASPIRIN                     Brad Wilson       PERSON
# 54   ASPIRIN                    Jonnie Uturn       PERSON
# 55   ASPIRIN                   Jim O'Connell       PERSON
# 66   ASPIRIN                   Dagny Taggart       PERSON
# 68   ASPIRIN                Danielle Barrila       PERSON
# 76   ASPIRIN                   Steve Steward       PERSON
# 77   ASPIRIN                 6 feet of Snark       PERSON
#
#                                             TextEntity  hasDrug  hasSymptom  \
# 161                                                 []    False       False
# 35                                                  []    False       False
# 315                                       ['CARDINAL']    False       False
# 2                                           ['PERSON']    False       False
# 5                                      ['ORG', 'DATE']    False       False
# 8                                                   []    False       False
# 10                                                  []    False       False
# 11                           ['DATE', 'ORG', 'PERSON']    False       False
# 19   ['CARDINAL', 'CARDINAL', 'CARDINAL', 'CARDINAL...    False       False
# 20                                                  []    False       False
# 26                                                  []    False       False
# 30                                            ['DATE']    False       False
# 36                                                  []    False       False
# 45                                                  []    False       False
# 54                                                  []    False       False
# 55                                                  []    False       False
# 66                                                  []    False       False
# 68                                                  []    False       False
# 76                                      ['ORG', 'ORG']    False       False
# 77                                             ['ORG']    False       False
#
#                                                   Text
# 161  partied like a rock star. Note to self - you a...
# 35           @clutchbucket it tasted like baby aspirin
# 315             3 aspirin and a huge ass cup of coffee
# 2    @NatalieAPollard I've got some aspirin on hold...
# 5    @RobaAssi Been there last week end ruba, take ...
# 8    ha @JedidiahAyres - i had a good time too, too...
# 10   @lcicaza I wish, tendré que self medicate myse...
# 11   Well today was stressful but thanks to Aspirin...
# 19   For tea: half a bottle of whisky, half a bottl...
# 20                          No baby lots of aspirin...
# 26   @carlyyminkk bring me water , aspirin, and a c...
# 30   Discharged! It is indeed pericarditis. Need to...
# 36   @CarlBialik @andrewflowers I know, but that so...
# 45   Morning headache cure: Diet Coke w/ Splenda. P...
# 54                                  I need an aspirin.
# 55   bruised, sore and annoyed.  need aspirin, ice ...
# 66                  @repub9989 This is beyond aspirin!
# 68   @JRKFAVGIRL uh oh sounds like you need a drink...
# 76   @JakeVAnderson try a Bayer aspirin, a Tylenol,...
# 77   "@RealDMK: @LetLuvRul might want to throw in a...

# %%
personalTweets = df[df.SourceEntity == 'PERSON']
personalTweets
# Out:
#        Product                              Name SourceEntity  \
# 2      ASPIRIN                 Charlotte Pollard       PERSON
# 5      ASPIRIN                      Nabil Kilany       PERSON
# 8      ASPIRIN                    Richard Thomas       PERSON
# 10     ASPIRIN                    Nati Baquerizo       PERSON
# 11     ASPIRIN                      Trisha Blish       PERSON
# 19     ASPIRIN                       Greg McLeod       PERSON
# 20     ASPIRIN                       Lloyd Smith       PERSON
# 26     ASPIRIN                       Katt  🧚🏽‍♀️       PERSON
# 30     ASPIRIN                    Mikey says hey       PERSON
# 36     ASPIRIN                     Louisa Thomas       PERSON
# 45     ASPIRIN                       Brad Wilson       PERSON
# 54     ASPIRIN                      Jonnie Uturn       PERSON
# 55     ASPIRIN                     Jim O'Connell       PERSON
# 66     ASPIRIN                     Dagny Taggart       PERSON
# 68     ASPIRIN                  Danielle Barrila       PERSON
# 76     ASPIRIN                     Steve Steward       PERSON
# 77     ASPIRIN                   6 feet of Snark       PERSON
# 79     ASPIRIN                      Kelsey Grant       PERSON
# 81     ASPIRIN                     J. D. William       PERSON
# 86     ASPIRIN               Matthew Paul Turner       PERSON
# 87     ASPIRIN               Jack Daniel Francis       PERSON
# 91     ASPIRIN                      Brad Bigelow       PERSON
# 92     ASPIRIN                      Bret Clement       PERSON
# 94     ASPIRIN                      Eric Barroca       PERSON
# 95     ASPIRIN                 Micheline Maynard       PERSON
# 96     ASPIRIN                     Tiffany Li Lú       PERSON
# 102    ASPIRIN                     Larry Pollock       PERSON
# 119    ASPIRIN                   Michael T. Rose       PERSON
# 124    ASPIRIN                     Kameron Lindo       PERSON
# 133    ASPIRIN                   Miss Yulie Rauf       PERSON
# ..         ...                               ...          ...
# 310  CELECOXIB                   Jina Riggs M.D.       PERSON
# 316  CELECOXIB                   Jina Riggs M.D.       PERSON
# 322  CELECOXIB                   Jina Riggs M.D.       PERSON
# 16   CELECOXIB                    Maija Haavisto       PERSON
# 36   CELECOXIB                    Michael Makris       PERSON
# 101  CELECOXIB                 Stéphane Charette       PERSON
# 107  CELECOXIB                  Dr Alex Concorde       PERSON
# 115  CELECOXIB                       Bob Boulder       PERSON
# 139  CELECOXIB                   Katherine Burns       PERSON
# 181  CELECOXIB  Wafik S. El-Deiry, MD, PhD, FACP       PERSON
# 223  CELECOXIB                       Debbie Reed       PERSON
# 237  CELECOXIB                      Nellie Gabor       PERSON
# 279  CELECOXIB                      Nellie Gabor       PERSON
# 280  CELECOXIB                      Nellie Gabor       PERSON
# 296  CELECOXIB                   Nicole Roberson       PERSON
# 44   CELECOXIB                   Bodjie Bautista       PERSON
# 48   CELECOXIB                   Deborah Coryell       PERSON
# 100  CELECOXIB                    Maija Haavisto       PERSON
# 110  CELECOXIB                    Boutros Hearty       PERSON
# 121  CELECOXIB                  Joviana Humpatch       PERSON
# 169  CELECOXIB                  H. Jack West, MD       PERSON
# 250  CELECOXIB                     James Hawkins       PERSON
# 287  CELECOXIB               Ma. Angelie Maglana       PERSON
# 26   CELECOXIB                  Gianni Halagueña       PERSON
# 123  CELECOXIB              Glenn D. Cohen. M.D.       PERSON
# 249  CELECOXIB                     James Hawkins       PERSON
# 251  CELECOXIB                      Susan Murphy       PERSON
# 256  CELECOXIB              Raymond Sue, DC CSCS       PERSON
# 285  CELECOXIB                       John Morley       PERSON
# 307  CELECOXIB                   Drew A Rosielle       PERSON
#
#                                             TextEntity  hasDrug  hasSymptom  \
# 2                                           ['PERSON']    False       False
# 5                                      ['ORG', 'DATE']    False       False
# 8                                                   []    False       False
# 10                                                  []    False       False
# 11                           ['DATE', 'ORG', 'PERSON']    False       False
# 19   ['CARDINAL', 'CARDINAL', 'CARDINAL', 'CARDINAL...    False       False
# 20                                                  []    False       False
# 26                                                  []    False       False
# 30                                            ['DATE']    False       False
# 36                                                  []    False       False
# 45                                                  []    False       False
# 54                                                  []    False       False
# 55                                                  []    False       False
# 66                                                  []    False       False
# 68                                                  []    False       False
# 76                                      ['ORG', 'ORG']    False       False
# 77                                             ['ORG']    False       False
# 79                                                  []    False       False
# 81                                        ['CARDINAL']    False       False
# 86                                                  []    False       False
# 87                                             ['ORG']    False       False
# 91                                                  []    False       False
# 92                                                  []    False       False
# 94                                                  []    False       False
# 95                                                  []    False       False
# 96                                                  []    False       False
# 102                                            ['ORG']    False       False
# 119                                            ['ORG']    False       False
# 124                                                 []    False       False
# 133                                                 []    False       False
# ..                                                 ...      ...         ...
# 310                                       ['CARDINAL']    False       False
# 316                           ['CARDINAL', 'CARDINAL']    False       False
# 322                           ['CARDINAL', 'CARDINAL']    False       False
# 16                          ['ORG', 'Disease_Symptom']    False        True
# 36   ['ORG', 'ORG', 'Disease_Symptom', 'ORG', 'ORG'...    False        True
# 101     ['Disease_Symptom', 'Disease_Symptom', 'DATE']    False        True
# 107             ['Disease_Symptom', 'Disease_Symptom']    False        True
# 115             ['Disease_Symptom', 'Disease_Symptom']    False        True
# 139                         ['ORG', 'Disease_Symptom']    False        True
# 181                         ['ORG', 'Disease_Symptom']    False        True
# 223        ['ORG', 'Disease_Symptom', 'ORG', 'PERSON']    False        True
# 237                                ['Disease_Symptom']    False        True
# 279                                ['Disease_Symptom']    False        True
# 280                                ['Disease_Symptom']    False        True
# 296      ['Disease_Symptom', 'Disease_Symptom', 'ORG']    False        True
# 44                                            ['Drug']     True       False
# 48                                    ['Drug', 'Drug']     True       False
# 100                                           ['Drug']     True       False
# 110                                   ['Drug', 'Drug']     True       False
# 121                                           ['Drug']     True       False
# 169                      ['ORG', 'Drug', 'ORG', 'ORG']     True       False
# 250                                           ['Drug']     True       False
# 287                                           ['Drug']     True       False
# 26                 ['Drug', 'Disease_Symptom', 'Drug']     True        True
# 123  ['Drug', 'Disease_Symptom', 'Drug', 'CARDINAL'...     True        True
# 249                        ['Drug', 'Disease_Symptom']     True        True
# 251                        ['Drug', 'Disease_Symptom']     True        True
# 256                        ['Drug', 'Disease_Symptom']     True        True
# 285                ['Drug', 'Disease_Symptom', 'DATE']     True        True
# 307                        ['Drug', 'Disease_Symptom']     True        True
#
#                                                   Text
# 2    @NatalieAPollard I've got some aspirin on hold...
# 5    @RobaAssi Been there last week end ruba, take ...
# 8    ha @JedidiahAyres - i had a good time too, too...
# 10   @lcicaza I wish, tendré que self medicate myse...
# 11   Well today was stressful but thanks to Aspirin...
# 19   For tea: half a bottle of whisky, half a bottl...
# 20                          No baby lots of aspirin...
# 26   @carlyyminkk bring me water , aspirin, and a c...
# 30   Discharged! It is indeed pericarditis. Need to...
# 36   @CarlBialik @andrewflowers I know, but that so...
# 45   Morning headache cure: Diet Coke w/ Splenda. P...
# 54                                  I need an aspirin.
# 55   bruised, sore and annoyed.  need aspirin, ice ...
# 66                  @repub9989 This is beyond aspirin!
# 68   @JRKFAVGIRL uh oh sounds like you need a drink...
# 76   @JakeVAnderson try a Bayer aspirin, a Tylenol,...
# 77   "@RealDMK: @LetLuvRul might want to throw in a...
# 79   I would give anything for some aspirin, cuddle...
# 81   Cold Remedy: Take 2 aspirin & call me in the m...
# 86   @bradbig hardly like "handing out aspirin." bu...
# 87   @tobydawson haha baby aspirin good choice if y...
# 91   @JesusNeedsNewPR @SaintMateo big deal about su...
# 92   For all of you CMS Haiku hobbyists RT @CherylM...
# 94   :-) RT @CherylMcKinnon New blog post @ Candy a...
# 95   In nearly all cases, the body accepts stents w...
# 96   ...but what I really need right now is an aspi...
# 102  @elixirgraphics - I use aspirin or white willo...
# 119  @hotdogsladies "Brass Aspirin" is a pretty goo...
# 124  Slight toothache = headache. When is this aspi...
# 133  Bangun tdur wif bad condition,,I get fever,n I...
# ..                                                 ...
# 310  celecoxib medication | what is celecoxib used ...
# 316  celecoxib high | celecoxib 200 mg capsules | w...
# 322  celecoxib 200 mg | celecoxib 200mg | what is c...
# 16   Niacinamide doesn't seem to agree with me. Mig...
# 36   Surprising story: A company called Tremeau wil...
# 101  In serious back pain. I dug out my old back pa...
# 107  PNEI/Pain etc: Loxoprofen sodium and celecoxib...
# 115  Loxoprofen sodium and celecoxib for postoperat...
# 139  Yes, there are concerns and our patients were ...
# 181  Celecoxib has shown effects on polyp growth in...
# 223  Biological Activity of Celecoxib in the Bronch...
# 237  heart disease celecoxib: http://terbinafinehcl...
# 279  heart disease celecoxib: http://terbinafinehcl...
# 280  heart disease celecoxib: http://terbinafinehcl...
# 296  Pt w\ hx of GI bleeding or stomach probs w/ tr...
# 44   etoricoxib 90mg OD given with or without meals...
# 48   amoxicillin erythromycin: buy effexor pills , ...
# 100  Woke up to a monstrous headache. A hefty dose ...
# 110    arthritis relief celecoxib generic for celebrex
# 121  http://readybot.com/bestsellers/et1222.html … ...
# 169  Large trial of COX-2 inhibitor celebrex (celec...
# 250  Celecoxib adjunctive therapy helpful for acute...
# 287                          Celecoxib to save the day
# 26   I have to take celecoxib to ease the kidney pa...
# 123  Chondroitin sulfate and glucosamine for painfu...
# 249  Celecoxib adjunctive therapy helpful for acute...
# 251  Famciclovir, celecoxib combo found effective t...
# 256  Famciclovir, celecoxib combo found effective t...
# 285  Celecoxib, ibuprofen, diclofenac, naproxen, an...
# 307  T1 asked a pharmacist about anti platelet effe...
#
# [19923 rows x 7 columns]

# %%
tp = df[(df.hasDrug == True) & (df.hasSymptom == True)]
tp.groupby('Product').size()
# Out:
# Product
# ACETAMINOPHEN            9
# ACETAMINOPHEN.           9
# ACETYLSALICYLIC ACID     2
# ACIPHEX                  1
# ACYCLOVIR.               4
# ADVAIR HFA               1
# ADVIL                    1
# ALBUTEROL                2
# ALBUTEROL.               2
# ALEVE                    9
# ALLEGRA                  4
# ALLOPURINOL              4
# ALLOPURINOL.             4
# ALPRAZOLAM.              4
# AMBIEN                   4
# AMITRIPTYLINE           24
# AMLODIPINE              10
# ASPIRIN                  3
# ASPIRIN.                 3
# ATENOLOL                 3
# ATENOLOL.                3
# ATIVAN                   8
# ATORVASTATIN             6
# AVANDIA                  3
# BACLOFEN.               19
# BENADRYL                19
# BISOPROLOL               1
# CALCIUM                  2
# CARVEDILOL.             17
# CELEBREX                 8
#                         ..
# SPIRIVA                  2
# SPIRONOLACTONE.          4
# SYMBICORT               12
# SYNTHROID                7
# TAMSULOSIN               3
# TOPAMAX                 46
# TOPROL XL                2
# TRAMADOL                21
# TRAMADOL.               21
# TRAZODONE               60
# TYLENOL                 12
# VENTOLIN                 4
# VICODIN                  9
# VIOXX                   10
# VITAMIN D                1
# VITAMIN E                7
# WARFARIN                23
# WARFARIN SODIUM          7
# WELLBUTRIN              28
# XANAX                   11
# XARELTO                  1
# XYREM                   15
# ZANTAC                   4
# ZETIA                    4
# ZOCOR                   10
# ZOFRAN                  13
# ZOLOFT                  17
# ZOLPIDEM                 6
# ZOMETA                  10
# ZYRTEC                  22
# Length: 176, dtype: int64

# %%
total_correct = len(tp)
total_personal_tweets = len(personalTweets)

print(f"Total Correctly identified Drug Name and Symptom/Total Personal Tweets: {total_correct}/{total_personal_tweets}")
print(f"Identified:  {int(total_correct/total_personal_tweets*100)} %")

# TODO: Display Text Entity and highlight of the tweet texts 
tp
# Out:
# Total Correctly identified Drug Name and Symptom/Total Personal Tweets: 2271/19923
# Identified:  11 %
#         Product                             Name SourceEntity  \
# 64      ASPIRIN                      Alice Hayes       PERSON
# 312     ASPIRIN                         cesultra      UNKNOWN
# 313     ASPIRIN                         cesultra      UNKNOWN
# 44     ASPIRIN.                      Alice Hayes       PERSON
# 371    ASPIRIN.                         cesultra      UNKNOWN
# 372    ASPIRIN.                         cesultra      UNKNOWN
# 46     CELEBREX                      Dennis Raye       PERSON
# 95     CELEBREX                  Jina Riggs M.D.       PERSON
# 160    CELEBREX                  Sextus Fulloway       PERSON
# 168    CELEBREX                    Batya Mcgiven       PERSON
# 173    CELEBREX                  Santana Matusov       PERSON
# 45     CELEBREX                 Medinews netwrok      UNKNOWN
# 86     CELEBREX             BackyardClimatChange      UNKNOWN
# 374    CELEBREX                          dominic      UNKNOWN
# 92   IBUPROFEN.                Marissa Henson△⃒⃘       PERSON
# 228  IBUPROFEN.                  Lynn Stephenson       PERSON
# 3    IBUPROFEN.                   Dr. Turtle Esq      UNKNOWN
# 31   IBUPROFEN.                     Guac Goddess      UNKNOWN
# 34   IBUPROFEN.                          Kee Wes      UNKNOWN
# 37   IBUPROFEN.                            Laura      UNKNOWN
# 109  IBUPROFEN.                     flat earther      UNKNOWN
# 113  IBUPROFEN.               A Chivalrous Bitch      UNKNOWN
# 137  IBUPROFEN.                           Rachel      UNKNOWN
# 193  IBUPROFEN.                            James      UNKNOWN
# 217  IBUPROFEN.                         lasersox      UNKNOWN
# 258  IBUPROFEN.                            addie      UNKNOWN
# 287  IBUPROFEN.                    Queen Kay  ❤️      UNKNOWN
# 294  IBUPROFEN.                         華胥の亡霊  🍥      UNKNOWN
# 321  IBUPROFEN.                          tгєίร 🌵      UNKNOWN
# 324  IBUPROFEN.              Abbacchio’s Fursona      UNKNOWN
# ..          ...                              ...          ...
# 163    LEVAQUIN                   Killer Parrot™      UNKNOWN
# 214    LEVAQUIN                     Ed DeAndrade      UNKNOWN
# 250    LEVAQUIN                              lex      UNKNOWN
# 280    LEVAQUIN                   FightBigPharma      UNKNOWN
# 308    LEVAQUIN  “Beto”Lynne4America 🇺🇸 🇺🇸 🇺🇸 🇺🇸      UNKNOWN
# 325    LEVAQUIN                        Dr. P.Kae      UNKNOWN
# 330    LEVAQUIN                            erika      UNKNOWN
# 26    CELECOXIB                 Gianni Halagueña       PERSON
# 123   CELECOXIB             Glenn D. Cohen. M.D.       PERSON
# 249   CELECOXIB                    James Hawkins       PERSON
# 251   CELECOXIB                     Susan Murphy       PERSON
# 256   CELECOXIB             Raymond Sue, DC CSCS       PERSON
# 285   CELECOXIB                      John Morley       PERSON
# 307   CELECOXIB                  Drew A Rosielle       PERSON
# 2     CELECOXIB                         Senology      UNKNOWN
# 9     CELECOXIB                        Alex Wong      UNKNOWN
# 22    CELECOXIB                  torpedobeat.mp4      UNKNOWN
# 102   CELECOXIB                 Medinews netwrok      UNKNOWN
# 126   CELECOXIB                               De      UNKNOWN
# 130   CELECOXIB              Cleveland Clinic MD      UNKNOWN
# 161   CELECOXIB                           Ale C.      UNKNOWN
# 205   CELECOXIB                           MDLinx      UNKNOWN
# 219   CELECOXIB                        dc trials      UNKNOWN
# 247   CELECOXIB                   TheBiotechLand      UNKNOWN
# 255   CELECOXIB             Seattle Chiropractor      UNKNOWN
# 263   CELECOXIB                     ANZJSurg.com      UNKNOWN
# 292   CELECOXIB                       Rene Sugar      UNKNOWN
# 295   CELECOXIB                              👁‍🗨      UNKNOWN
# 300   CELECOXIB                Nociception Music      UNKNOWN
# 323   CELECOXIB                    OrthoEvidence      UNKNOWN
#
#                                             TextEntity  hasDrug  hasSymptom  \
# 64                         ['Drug', 'Disease_Symptom']     True        True
# 312   ['GPE', 'ORG', 'Drug', 'GPE', 'Disease_Symptom']     True        True
# 313   ['GPE', 'ORG', 'Drug', 'GPE', 'Disease_Symptom']     True        True
# 44                         ['Drug', 'Disease_Symptom']     True        True
# 371   ['GPE', 'ORG', 'Drug', 'GPE', 'Disease_Symptom']     True        True
# 372   ['GPE', 'ORG', 'Drug', 'GPE', 'Disease_Symptom']     True        True
# 46                         ['Drug', 'Disease_Symptom']     True        True
# 95                 ['Drug', 'Drug', 'Disease_Symptom']     True        True
# 160                 ['Drug', 'Disease_Symptom', 'ORG']     True        True
# 168                        ['Drug', 'Disease_Symptom']     True        True
# 173                        ['Drug', 'Disease_Symptom']     True        True
# 45                         ['Drug', 'Disease_Symptom']     True        True
# 86     ['Drug', 'Disease_Symptom', 'Drug', 'CARDINAL']     True        True
# 374            ['Drug', 'CARDINAL', 'Disease_Symptom']     True        True
# 92                         ['Drug', 'Disease_Symptom']     True        True
# 228                        ['Disease_Symptom', 'Drug']     True        True
# 3                          ['Drug', 'Disease_Symptom']     True        True
# 31             ['Disease_Symptom', 'Drug', 'CARDINAL']     True        True
# 34                         ['Drug', 'Disease_Symptom']     True        True
# 37                 ['TIME', 'Drug', 'Disease_Symptom']     True        True
# 109  ['PERSON', 'DATE', 'Disease_Symptom', 'Drug', ...     True        True
# 113                        ['Drug', 'Disease_Symptom']     True        True
# 137                        ['Drug', 'Disease_Symptom']     True        True
# 193                        ['Drug', 'Disease_Symptom']     True        True
# 217                        ['Disease_Symptom', 'Drug']     True        True
# 258                        ['Drug', 'Disease_Symptom']     True        True
# 287                        ['Drug', 'Disease_Symptom']     True        True
# 294                ['Drug', 'DATE', 'Disease_Symptom']     True        True
# 321     ['Drug', 'ORG', 'Disease_Symptom', 'CARDINAL']     True        True
# 324                        ['Drug', 'Disease_Symptom']     True        True
# ..                                                 ...      ...         ...
# 163                        ['Disease_Symptom', 'Drug']     True        True
# 214                        ['Drug', 'Disease_Symptom']     True        True
# 250                        ['Disease_Symptom', 'Drug']     True        True
# 280                        ['Drug', 'Disease_Symptom']     True        True
# 308                        ['Drug', 'Disease_Symptom']     True        True
# 325        ['DATE', 'Drug', 'Disease_Symptom', 'Drug']     True        True
# 330                        ['Drug', 'Disease_Symptom']     True        True
# 26                 ['Drug', 'Disease_Symptom', 'Drug']     True        True
# 123  ['Drug', 'Disease_Symptom', 'Drug', 'CARDINAL'...     True        True
# 249                        ['Drug', 'Disease_Symptom']     True        True
# 251                        ['Drug', 'Disease_Symptom']     True        True
# 256                        ['Drug', 'Disease_Symptom']     True        True
# 285                ['Drug', 'Disease_Symptom', 'DATE']     True        True
# 307                        ['Drug', 'Disease_Symptom']     True        True
# 2                          ['Drug', 'Disease_Symptom']     True        True
# 9                          ['Drug', 'Disease_Symptom']     True        True
# 22   ['Drug', 'Drug', 'Disease_Symptom', 'Disease_S...     True        True
# 102                 ['Drug', 'Disease_Symptom', 'ORG']     True        True
# 126          ['Drug', 'ORG', 'ORG', 'Disease_Symptom']     True        True
# 130                 ['Drug', 'Disease_Symptom', 'ORG']     True        True
# 161                        ['Drug', 'Disease_Symptom']     True        True
# 205                        ['Drug', 'Disease_Symptom']     True        True
# 219                        ['Drug', 'Disease_Symptom']     True        True
# 247                        ['Disease_Symptom', 'Drug']     True        True
# 255                        ['Drug', 'Disease_Symptom']     True        True
# 263                        ['Drug', 'Disease_Symptom']     True        True
# 292                 ['Drug', 'Disease_Symptom', 'ORG']     True        True
# 295  ['TIME', 'Disease_Symptom', 'Disease_Symptom',...     True        True
# 300                        ['Disease_Symptom', 'Drug']     True        True
# 323                ['Drug', 'NORP', 'Disease_Symptom']     True        True
#
#                                                   Text
# 64   Why aspirin and paracetamol could be making yo...
# 312  Russia has an  opioid abuse problem as big as ...
# 313  Russia has an  opioid abuse problem as big as ...
# 44   Why aspirin and paracetamol could be making yo...
# 371  Russia has an  opioid abuse problem as big as ...
# 372  Russia has an  opioid abuse problem as big as ...
# 46   New blog post: Celebrex disrupts heart rhythm ...
# 95   celebrex uses | celebrex high | generic celebr...
# 160  Celebrex appears to have some activity against...
# 168  celebrex over the counter pain reliever http:/...
# 173      celebrex for migraines http://bit.ly/1Om9FfT
# 45   medinews: Celebrex disrupts heart rhythm in fr...
# 86   Traditional celebrex and risk of stroke moulde...
# 374  $KTOV nobody is going to give a shit about Gen...
# 92   Someone bring me ibuprofen before my head expl...
# 228  Had headache all day. Took ibuprofen, drank lo...
# 3    can't sleep. ear hurts too much. going to wait...
# 31   Hopefully this cough syrup is codeine based.  ...
# 34   Hmm should I take ibuprofen for the pain or a ...
# 37   have about 20 minutes before the latest dose o...
# 109  I attacked anyone who found Lil Pump hot for l...
# 113  take ibuprofen before hand that should help le...
# 137  @jaimers327 Thanks. Unfortunately I can't take...
# 193  I have an honest migrane i'm about to overdose...
# 217  @ldaley coffee withdrawal generally only lasts...
# 258  not even 800mg ibuprofen can help me now...so ...
# 287  I could never be a pill popper. I barely like ...
# 294  At least the ibuprofen I took this morning is ...
# 321  The addiction to coffee/ caffeine is real, I’v...
# 324  You know it’s time to go to the dentist when y...
# ..                                                 ...
# 163  @JeffMusk but you know how she is allergic to ...
# 214  So this patient tells me the levaquin I prescr...
# 250  @boredERdoc @Dr_B_PharmD levaquin. I was aller...
# 280  #JNJASM15 J&amp;J's Levaquin antibiotic cured ...
# 308  Thanks for your drug Levaquin. It ruined my li...
# 325  Why the doctor yesterday prescribed this lady ...
# 330  "Benadryl helped the severe shaking (central n...
# 26   I have to take celecoxib to ease the kidney pa...
# 123  Chondroitin sulfate and glucosamine for painfu...
# 249  Celecoxib adjunctive therapy helpful for acute...
# 251  Famciclovir, celecoxib combo found effective t...
# 256  Famciclovir, celecoxib combo found effective t...
# 285  Celecoxib, ibuprofen, diclofenac, naproxen, an...
# 307  T1 asked a pharmacist about anti platelet effe...
# 2    The addition of celecoxib to concurrent chemor...
# 9    Clinical study: Celecoxib drug may treat breas...
# 22   main complaint: the complexity of cox-2 inhibi...
# 102  medinews: Effect of celecoxib on restenosis af...
# 126  Is naproxen unavailable or they refusing to gi...
# 130  In PRECISION substudy, researchers looked at t...
# 161  Celecoxib enhances radiosensitivity of hypoxic...
# 205  Oncology Biological activity of celecoxib in t...
# 219  naturalistic safety registry of celecoxib ) & ...
# 247  @jdbear Celecoxib increase blood pressure of 2...
# 255  Famciclovir, celecoxib combo found effective t...
# 263  Efficacy and safety of low-dose celecoxib in r...
# 292  Doxycycline makes cancer cells metabolically i...
# 295  WENT TO THE ER AT 1:30 AM BECAUSE “DOC, I HAD ...
# 300  That knee surgery really eff’d me up: I just t...
# 323  Celecoxib and naproxen beneficial in Asian pat...
#
# [2271 rows x 7 columns]

# %%
DrugCountDF = df[(df.hasDrug == True)]
total_product_recognized = len(DrugCountDF)
total_personal_tweets = len(personalTweets)
print(f"Total Correctly identified Drug Name and Symptom/Total Personal Tweets: {total_product_recognized}/{total_personal_tweets}")
print(f"Correctness: {int(total_product_recognized/total_personal_tweets*100)}%")
# Out:
# Total Correctly identified Drug Name and Symptom/Total Personal Tweets: 10321/19923
# Correctness: 51%

# %% [markdown]
# # After finding these result to retrain the model see if we can get better result.

# %%
prods = tp.Product.unique()
products = list(map(lambda p: p, prods))
print(f"Number of products to monitor : {len(products)}")
# Out:
# Number of products to monitor : 176

# %% [markdown]
# # Real Time Twitter Streaming Monitoring

# %%
from IPython.display import HTML, display
from datetime import datetime


name = "Dr Gordon Caldwell"
text = "No it was after the ibuprofen for the gout caused by the furosemide given to clear oedema from too much iv fluids https://twitter.com/betabetic/status/676544651248189443 …"

class DisplayTwitterDetector:     
    color = {
        'DRUG'           :'#bfeeb7', 
        'DISEASE_SYMPTOM':'#ffbf00', 
        #'PERSON'         :'#7aecec', 
        #'ORG'            :'#A9CCE3',
        'OTHER'          :'#D3D3D3'
    }
    def detect(self, name, text, displayDetected = 'both'):
        tw = TwitterWatch(tagger)
        processed = tw.detect(name, text)         
        if(processed['hasDrug'] and processed['hasSymptom']):             
            self.displayResult(name, processed)    
            return processed
        elif (displayDetected == 'either'):
            if(len(processed['TextEntity']) > 0):
                self.displayResult(name, processed)            
        else:
            if(displayDetected == 'none'):                
                self.displayResult(name, processed)   
        return None
        
    def findEntity(self, p, start, end):
        entities = p['entities']['entities']
        for ent in entities:
            if(start == ent['start_pos'] and end == ent['end_pos']):
                return ent                    
        return None
    def getHtmlText(self, color, text, label):
        return f"""
            <mark class="entity" style="background: {color}; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">{text}
            <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">{label}</span></mark>
        """

    def getColor(self, entityType):
        if(entityType in self.color): 
            return self.color[entityType]
        else:
            return self.color['OTHER']
        
    def displayResult(self,name, p):
        now = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
        result = f"""<span>{now}</span> <span style="padding-left:5em">{name}</span> <span style="padding-left:5em">"""
        for token in p['sentence']:
            ent = self.findEntity(p, token.start_pos,  token.end_pos)
            if(ent != None):
                result = result + ' '+ self.getHtmlText(self.getColor(ent['type'].upper()), ent['text'], ent['type'])
            else:
                result = result + ' ' + token.text
        result = result + "</span>"
        h = HTML(result); 
        display(h)

d = DisplayTwitterDetector()
d.detect(name, text)
d.detect(name, """RT BougieLa: It IS killing us. When folks are having strokes because they can’t afford their blood pressure meds, and diabetics are going…""", 'either')
# Out:
# <span>2019-03-21 12:11:02</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> No it was after the ibuprofen for the gout caused by the
#             <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">furosemide
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Drug</span></mark>
#          given to clear
#             <mark class="entity" style="background: #ffbf00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">oedema
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease_Symptom</span></mark>
#          from too much iv fluids https://twitter.com/betabetic/status/676544651248189443 …</span>
# <span>2019-03-21 12:11:02</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT BougieLa: It IS killing us. When folks are having
#             <mark class="entity" style="background: #ffbf00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">strokes
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease_Symptom</span></mark>
#          because they can’t afford their blood pressure meds, and
#             <mark class="entity" style="background: #ffbf00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">diabetics
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease_Symptom</span></mark>
#          are going…</span>

# %% [markdown]
# # Personal Twitter Developer api only allows to track 400 max

# %%
df = getAdverseEvents(330)
products = df.term.unique()
products = list(map(lambda p: p.lower(), products))
print(f"Number of products to monitor : {len(products)}")
products
# Out:
# Number of products to monitor : 330
# ['aspirin',
#  'aspirin.',
#  'celebrex',
#  'ibuprofen.',
#  'acetaminophen',
#  'ibuprofen',
#  'lipitor',
#  'plavix',
#  'humira',
#  'vitamin d',
#  'metformin',
#  'omeprazole.',
#  'acetaminophen.',
#  'lisinopril.',
#  'lasix',
#  'nexium',
#  'amlodipine',
#  'acetylsalicylic acid',
#  'atorvastatin',
#  'synthroid',
#  'advil',
#  'lisinopril',
#  'gabapentin.',
#  'revlimid',
#  'prednisone.',
#  'simvastatin',
#  'methotrexate',
#  'lyrica',
#  'calcium',
#  'fish oil',
#  'prilosec',
#  'simvastatin.',
#  'crestor',
#  'omeprazole',
#  'folic acid.',
#  'furosemide.',
#  'vitamin d3',
#  'folic acid',
#  'naproxen.',
#  'enbrel',
#  'tylenol',
#  'xarelto',
#  'meloxicam.',
#  'protonix',
#  'furosemide',
#  'norvasc',
#  'metoprolol',
#  'atenolol',
#  'pantoprazole',
#  'dexamethasone.',
#  'cymbalta',
#  'prednisone',
#  'vitamin b12',
#  'naproxen',
#  'niaspan',
#  'xanax',
#  'zocor',
#  'clopidogrel',
#  'neurontin',
#  'lantus',
#  'mobic',
#  'levothyroxine.',
#  'prevacid',
#  'hydrochlorothiazide',
#  'motrin',
#  'paracetamol',
#  'spiriva',
#  'metoprolol.',
#  'avandia',
#  'multivitamin',
#  'metformin hcl',
#  'singulair',
#  'ambien',
#  'oxycodone',
#  'xyrem',
#  'vitamin c',
#  'hydrochlorothiazide.',
#  'zoloft',
#  'coumadin',
#  'allopurinol.',
#  'coreg',
#  'vioxx',
#  'zyrtec',
#  'atenolol.',
#  'diovan',
#  'doxycycline.',
#  'zofran',
#  'tramadol.',
#  'lexapro',
#  'carvedilol.',
#  'potassium',
#  'allopurinol',
#  'trazodone',
#  'citalopram',
#  'benadryl',
#  'bisoprolol',
#  'methotrexate.',
#  'gabapentin',
#  'levothyroxine sodium',
#  'ondansetron',
#  'acyclovir.',
#  'vicodin',
#  'magnesium',
#  'percocet',
#  'losartan.',
#  'zetia',
#  'hydrocodone',
#  'tramadol hcl',
#  'morphine',
#  'iron',
#  'albuterol',
#  'lorazepam.',
#  'ativan',
#  'meloxicam',
#  'insulin',
#  'flonase',
#  'ramipril.',
#  'zantac',
#  'norco',
#  'warfarin',
#  'heparin',
#  'potassium chloride',
#  'symbicort',
#  'metoprolol tartrate',
#  'ramipril',
#  'pravastatin',
#  'aleve',
#  'remicade',
#  'miralax',
#  'multivitamins',
#  'diphenhydramine.',
#  'colace',
#  'vitamin e',
#  'flexeril',
#  'plaquenil',
#  'toprol-xl',
#  'doxycycline',
#  'digoxin',
#  'flomax',
#  'fosamax',
#  'potassium chloride.',
#  'clonazepam.',
#  'baclofen.',
#  'proair hfa',
#  'seroquel',
#  'ranitidine',
#  'levothyroxine',
#  'claritin',
#  'lorazepam',
#  'alprazolam.',
#  'albuterol.',
#  'wellbutrin',
#  'spironolactone.',
#  'sertraline',
#  'pradaxa',
#  'advair hfa',
#  'prednisolone',
#  'prozac',
#  'naprosyn',
#  'lopressor',
#  'lansoprazole',
#  'humalog',
#  'multi-vitamin',
#  'aciphex',
#  'oxycontin',
#  'fluoxetine',
#  'amitriptyline',
#  'tamsulosin',
#  'klonopin',
#  'cozaar',
#  'nitroglycerin',
#  'celecoxib.',
#  'premarin',
#  'dexilant',
#  'zolpidem',
#  'lansoprazole.',
#  'celexa',
#  'metoprolol tartrate.',
#  'toprol xl',
#  'novolog',
#  'ecotrin',
#  'vimovo',
#  'allegra',
#  'glucophage',
#  'epipen',
#  'zometa',
#  'tramadol',
#  'januvia',
#  'effexor',
#  'paxil',
#  'ampyra',
#  'chantix',
#  'ventolin',
#  'clonazepam',
#  'dexamethasone',
#  'warfarin sodium',
#  'topamax',
#  'promethazine',
#  'levaquin',
#  'celecoxib',
#  'carvedilol',
#  'melatonin',
#  'prednisolone.',
#  'diazepam.',
#  'amoxicillin.',
#  'verapamil',
#  'alprazolam',
#  'yaz',
#  'spironolactone',
#  'actos',
#  'klor-con',
#  'advair diskus 100/50',
#  'valium',
#  'forteo',
#  'enalapril',
#  'diltiazem',
#  'cyclobenzaprine',
#  'excedrin',
#  'tecfidera',
#  'velcade',
#  'altace',
#  'bactrim',
#  'diclofenac',
#  'voltaren',
#  'yasmin',
#  'lortab',
#  'ranitidine.',
#  'amiodarone',
#  'lidocaine.',
#  'lovenox',
#  'fentanyl.',
#  'byetta',
#  'arava',
#  'vitamin b complex',
#  'glipizide.',
#  'salbutamol',
#  'aggrenox',
#  'glipizide',
#  'pepcid',
#  'loratadine.',
#  'multi-vitamins',
#  'benicar',
#  'tricor',
#  'vytorin',
#  'glucosamine',
#  'imdur',
#  'nitroglycerin.',
#  'ascorbic acid',
#  'amlodipine besylate.',
#  'biotin',
#  'adderall',
#  'diazepam',
#  'senna',
#  'aldactone',
#  'pomalyst',
#  'metoprolol succinate.',
#  'hydroxychloroquine',
#  'nasonex',
#  'centrum silver',
#  'hizentra',
#  'lovaza',
#  'pravastatin.',
#  'vancomycin',
#  'amitriptyline hcl',
#  'ultram',
#  'otezla',
#  'atorvastatin calcium',
#  'ferrous sulfate.',
#  'levothyroxine sodium.',
#  'glyburide',
#  'combivent',
#  'propranolol',
#  'digoxin.',
#  'prednisone tab',
#  'pravachol',
#  'rituxan',
#  'provigil',
#  'losartan',
#  'hydrocodone bitartrate and acetaminophen',
#  'nuvigil',
#  'xeljanz',
#  'methylprednisolone.',
#  'eliquis',
#  'valtrex',
#  'calcium carbonate',
#  'lamictal',
#  'abilify',
#  'enalapril maleate',
#  'atorvastatin calcium.',
#  'actemra',
#  'bextra',
#  'avonex',
#  'famotidine.',
#  'sodium chloride.',
#  'doxycycline hyclate.',
#  'dilaudid',
#  'losartan potassium.',
#  'magnesium oxide.',
#  'oxycodone hcl',
#  'compazine',
#  'simcor',
#  'levemir',
#  'metoprolol succinate',
#  'viagra',
#  'fentanyl',
#  'sulfasalazine.',
#  'amaryl',
#  'hydroxyzine',
#  'hydralazine',
#  'amoxicillin',
#  'nitrostat',
#  'glimepiride.',
#  'montelukast',
#  'venlafaxine',
#  'actonel',
#  'keppra',
#  'coenzyme q10',
#  'valsartan.',
#  'nexium 24hr',
#  'finasteride.',
#  'vitamin b-12',
#  'escitalopram',
#  'fenofibrate.',
#  'docusate',
#  'baclofen',
#  'clonidine.',
#  'codeine',
#  'decadron',
#  'advil pm',
#  'ciprofloxacin.']

# %%
from __future__ import absolute_import, print_function

import ipywidgets as widgets

from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

from IPython.display import clear_output, display
import json
from collections import deque


# Go to http://apps.twitter.com and create an app.
# The consumer key and secret will be generated for you after
consumer_key="6jWuKi5xOokKx65MI35Q"
consumer_secret="I0cqvp8CFhLe8Xer9GoJKLg6J0NfwHddjVUjIQFTeI"

# After the step above, you will be redirected to your app's page.
# Create an access token under the the "Your access token" section
access_token="127221870-92JvNvmBlrJt7bteAjM9csRA5LRHebTaH3FmKlzg"
access_token_secret="aRwTHxCTbnIk6Ba9drK8H8qGEfXBBo1rjGN4HZfy0BGKc"


    
class StdOutListener(StreamListener):    
    lines = deque([])
    def on_data(self, data):       
        tweet = json.loads(data)
        #if(len(self.lines)>5):
        #    self.lines.popleft()                        
        username = tweet['user']['name']
        text = tweet['text']
        d = DisplayTwitterDetector()
        r = d.detect(name, text, 'either')
        #r = detect(username, text)
        #if(r != None):            
            #self.lines.append(displayLine)
            #clear_output(wait=True)   
            #for line in self.lines:
            #    print(line)
        #else:
            #print(f"Not detected: {username}\t\t\t{text}")
    def on_error(self, status):
        print(status)

l = StdOutListener()
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
stream = Stream(auth, l)
print(f"Monitoring {len(products)} products ...")
stream.filter(languages=["en"], track=products)
# Out:
# Monitoring 330 products ...
# <span>2019-03-21 12:11:08</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT heyalyshahey: You have to take
#             <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Benadryl
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Drug</span></mark>
#          3 business days before you actually need it.</span>
# <span>2019-03-21 12:11:09</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT NewJerseyOAG: By taking down what may be
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">one
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#          of the deadliest drug mills ever dismantled in NJ, we’ve barred countless doses of fentany…</span>
# <span>2019-03-21 12:11:10</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT TheRock: Get hyped boys &amp; girls.
# My new PROJECTROCK underarmour BendBoundariesCollection is HERE!
# Enter the Iron Paradise &amp; see your…</span>
# <span>2019-03-21 12:11:10</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT chattyknana: Need to tell Purdue and Ohio millions of chronic
#             <mark class="entity" style="background: #ffbf00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">pain
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease_Symptom</span></mark>
#          patients behind
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Purdue!
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          We are NOT addicts! OH seek your blood $$$ e…</span>
# <span>2019-03-21 12:11:11</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT charlwynmcr: List of things I was exposed to at school and didn’t turn into:
#
# 1) oxbow lakes
# 2) The assassination of
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Archduke
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Franz Fer…</span>
# <span>2019-03-21 12:11:12</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT jinsooyng: when they got fake kidnapped and
#             <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">jungkook
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Drug</span></mark>
#          had on iron man socks https://t.co/IAfm7FdvmD</span>
# <span>2019-03-21 12:11:13</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT JbKnockout: Who needs
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">LSD
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          when instead you can have low iron and trip out every time you stand up too quickly</span>
# <span>2019-03-21 12:11:13</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em">
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">RT
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          F1: A three-time
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">F1
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          world champion 🏆🏆🏆
#
# An icon of the sport
#
# The legendary Ayrton Senna was born OnThisDay in 1960
#
# Gone, but never…</span>
# <span>2019-03-21 12:11:15</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em">
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">RT
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          F1: A three-time
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">F1
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          world champion 🏆🏆🏆
#
# An icon of the sport
#
# The legendary Ayrton Senna was born OnThisDay in 1960
#
# Gone, but never…</span>
# <span>2019-03-21 12:11:19</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT LynnPoliceDept:
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">The
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Lynn DTF, DEA and Mass State Police worked a joint investigation which resulted in
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">one
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#          arrest, the
#             <mark class="entity" style="background: #ffbf00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">seizure
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease_Symptom</span></mark>
#          of
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">two
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#          k…</span>
# <span>2019-03-21 12:11:19</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT AnaMardoll: gillibrandny It's physically possible to prescribe hydrocodone without
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Tylenol
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          -- in small doses throughout the day -- but…</span>
# <span>2019-03-21 12:11:19</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT HaydenRachelle5: yeah, and it’s filled with
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Claritin
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          and nasal spray https://t.co/e3aXB2qKnm</span>
# <span>2019-03-21 12:11:20</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT Public_Citizen: Orrin Hatch - $2,747,722 from
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Big
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Pharma
#
# Mitt Romney - $2,700,392 from
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Big
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Pharma
#
# Richard Burr - $1,554,962 from
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Big…
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span></mark>
#         </span>
# <span>2019-03-21 12:11:20</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> Interesting data presented by Dr. Cristopher Jones during his ACCJH keynote presentation showing that synthetic op… https://t.co/YqAzO6wDQA</span>
# <span>2019-03-21 12:11:21</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT itsJeffTiedrich: realDonaldTrump WhiteHouse the Big Boy President had a very busy Big Boy Day and now he's going to ride in his Big B…</span>
# <span>2019-03-21 12:11:21</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> I've watched too much Iron Chef to take
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Mark
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span></mark>
#
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Dacascos
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span></mark>
#          seriously in a film but BOY AM I EXCITED FOR THIS!!
#
# https://t.co/WOZ9P8mudD</span>
# <span>2019-03-21 12:11:21</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT caslon_valtoken: Caslon valium Token
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">1,000,000,000
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#          Airdrop for
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">first
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span></mark>
#
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">1000
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#          people,
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">1,000,000
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#          CVT EACH
#
# Name: CASLON VALIUM TOKEN
# Supply:…</span>
# <span>2019-03-21 12:11:22</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em">
#             <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Xanax
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Drug</span></mark>
#          be fucking up my emotions happy sad
#             <mark class="entity" style="background: #ffbf00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">angry
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease_Symptom</span></mark>
#          then giggly lol</span>
# <span>2019-03-21 12:11:23</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em">
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Lol
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span></mark>
#          I remember saying this for the fun of it but I guess be careful for what you ask for😂</span>
# <span>2019-03-21 12:11:24</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT propstore_com: Prop Store, in association with Marvel Entertainment, is proud to announce the MARVEL TELEVISION LIVE AUCTION.
# https://t…</span>
# <span>2019-03-21 12:11:24</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> Magic Senna</span>
# <span>2019-03-21 12:11:25</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT charlwynmcr: List of things I was exposed to at school and didn’t turn into:
#
# 1) oxbow lakes
# 2) The assassination of
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Archduke
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Franz Fer…</span>
# <span>2019-03-21 12:11:25</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT jinsooyng: when they got fake kidnapped and
#             <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">jungkook
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Drug</span></mark>
#          had on iron man socks https://t.co/IAfm7FdvmD</span>
# <span>2019-03-21 12:11:25</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT charlwynmcr: List of things I was exposed to at school and didn’t turn into:
#
# 1) oxbow lakes
# 2) The assassination of
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Archduke
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Franz Fer…</span>
# <span>2019-03-21 12:11:26</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT hyungwonope:
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Minhee
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          was unable to give the letter to the fan he pouts and keep bowing still so hyper and jumpy
#
# yes he is the vitamin c…</span>
# <span>2019-03-21 12:11:26</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> Roses cats! dead pansies you cat? Versus Wars Jurassic Lord . ,
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Independance
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Armagedon
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span></mark>
#          Saving Down Iron Zone Harry… https://t.co/Dk9QvfW4SD</span>
# <span>2019-03-21 12:11:27</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT NIH: News: NIH study finds no evidence that calcium increases risk of
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">AMD
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          https://t.co/J1A6nxm6mW</span>
# <span>2019-03-21 12:11:27</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> minhee is 10 years younger than minhyuk yall let's not tell minhyuk our
#             <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">minhyuk
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Drug</span></mark>
#          is young too 🙈</span>
# <span>2019-03-21 12:11:29</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT TheRock: Get hyped boys &amp; girls.
# My new PROJECTROCK underarmour BendBoundariesCollection is HERE!
# Enter the Iron Paradise &amp; see your…</span>
# <span>2019-03-21 12:11:30</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT NeolithicSheep: AnaMardoll gillibrandny My fave part of requiring it to be mixed with
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Tylenol
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          was that it was deliberately required t…</span>
# <span>2019-03-21 12:11:31</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT charlwynmcr: List of things I was exposed to at school and didn’t turn into:
#
# 1) oxbow lakes
# 2) The assassination of
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Archduke
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Franz Fer…</span>
# <span>2019-03-21 12:11:32</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT charlwynmcr: List of things I was exposed to at school and didn’t turn into:
#
# 1) oxbow lakes
# 2) The assassination of
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">Archduke
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Franz Fer…</span>
# <span>2019-03-21 12:11:32</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT rxcbd1: 📣TESTIMONIAL ALERT! NO MORE MORPHINE !! 🙏More AMAZING results from
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">CTFO
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">CBD
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          Oil! Get Yours Today! 🙌This is What I Use for My…</span>
# <span>2019-03-21 12:11:33</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT JamesMilner:
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">TBT
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span></mark>
#          364 days ago.... tougher times before I got my deluxe elite steam
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">3000
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#          iron 😀
# mysortofgadget lifebeforesocialmedi…</span>
# <span>2019-03-21 12:11:33</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT TheRock: Get hyped boys &amp; girls.
# My new PROJECTROCK underarmour BendBoundariesCollection is HERE!
# Enter the Iron Paradise &amp; see your…</span>
# <span>2019-03-21 12:11:33</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> RT DiabetesBros: Endo: “You’ve had
#             <mark class="entity" style="background: #ffbf00; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">diabetes
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">Disease_Symptom</span></mark>
#          for *literally* years. Why don’t you take your insulin BEFORE you eat? Why?!”
#
# Me: https://t.c…</span>
# <span>2019-03-21 12:11:34</span> <span style="padding-left:5em">Dr Gordon Caldwell</span> <span style="padding-left:5em"> Spring_Dosa Didn’t like iron and wine, will listen other
#             <mark class="entity" style="background: #D3D3D3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">two
#             <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span></mark>
#         </span>
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-175-828d732bafa0> in <module>
#      50 stream = Stream(auth, l)
#      51 print(f"Monitoring {len(products)} products ...")
# ---> 52 stream.filter(languages=["en"], track=products)
#      53
#      54
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# ~/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     440             else:
#     441                 cache_content = False
# --> 442                 data = self._fp.read(amt)
#     443                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     444                     # Close the connection when no data is returned
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~/anaconda3/lib/python3.7/http/client.py in readinto(self, b)
#     479
#     480         if self.chunked:
# --> 481             return self._readinto_chunked(b)
#     482
#     483         if self.length is not None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readinto_chunked(self, b)
#     574         try:
#     575             while True:
# --> 576                 chunk_left = self._get_chunk_left()
#     577                 if chunk_left is None:
#     578                     return total_bytes
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     542                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     543             try:
# --> 544                 chunk_left = self._read_next_chunk_size()
#     545             except ValueError:
#     546                 raise IncompleteRead(b'')
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     502     def _read_next_chunk_size(self):
#     503         # Read the next chunk size from the file
# --> 504         line = self.fp.readline(_MAXLINE + 1)
#     505         if len(line) > _MAXLINE:
#     506             raise LineTooLong("chunk size")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:
